# %%
import warnings
warnings.filterwarnings('ignore')
from gensim.models import FastText
from tqdm import tqdm_notebook
import numpy as np
import cntk as C

# %%
"""
Configuration
"""
embedding_path = '../embedding/fasttext_384_15_5_50_sg0.bin'
train_data = '../data/train.ctf'
valid_data = '../data/dev.ctf'
test_data = 'test'
valid_minibatch_size = 1024
num_validation = 10000
minibatch_size = 1024
epoch_size = 4000000
embedding_dim = 384
learning_rate = 5
hidden_dim = 256
max_epochs = 300
log_freq = 2000
dropout = 0.2
version = 'train'

# %%
"""
CUDNN approach rnn stack
"""
from cntk.layers.blocks import _INFERRED
def OptimizedRnnStack(hidden_dim, num_layers=1, recurrent_op='lstm', bidirectional=True, 
                      use_cudnn=True, name=''):
    if use_cudnn:
        W = C.parameter(_INFERRED + (hidden_dim,), init=C.glorot_uniform())
        def func(x):
            return C.optimized_rnnstack(x, W, hidden_dim, num_layers, bidirectional, 
                                        recurrent_op=recurrent_op, name=name)
        return func
    else:
        raise NotImplementedError

# %%
"""
Step function used to calculate sequence length
"""
def plus1(x, y):
    return x + 1 + (y - y)

# %%
"""
Model Class
"""
from collections import defaultdict
class Model:
    def __init__(self):
        self.embedding_path = embedding_path
        self.fmodel = FastText.load(self.embedding_path)
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.word_dim = len(self.fmodel.wv.vocab) + 1
        self.vocab = defaultdict(int)
        self.dropout = dropout
        self.use_cudnn = True
        
        index = 1
        for vocab in self.fmodel.wv.vocab:
            self.vocab[vocab] = index
            index += 1
        
    def embed(self):
        vec = np.zeros((self.word_dim, self.embedding_dim), dtype=np.float32)

        for vocab in self.fmodel.wv.vocab:
            vec[self.vocab[vocab]] = self.fmodel.wv[vocab]
        
        embedding = C.parameter(shape=vec.shape, init=vec)
        
        def func(context):
            return C.times(context, embedding)
        
        return func
        
    def input_layer(self, c1w, c2w):
        c1w_ph = C.placeholder()
        c2w_ph = C.placeholder()
        
        input_words = C.placeholder(shape=(self.word_dim))
        
        embedded = self.embed()(input_words)
        processed = OptimizedRnnStack(self.hidden_dim,
                       num_layers=1, bidirectional=True, use_cudnn=True, name='input_rnn')(embedded)
        
        c1_processed = processed.clone(C.CloneMethod.share, {input_words: c1w_ph})
        c2_processed = processed.clone(C.CloneMethod.share, {input_words: c2w_ph})
        
        return C.as_block(
            C.combine([c1_processed, c2_processed]),
            [(c1w_ph, c1w), (c2w_ph, c2w)],
            'input_layer',
            'input_layer'
        )
    
    def attention_layer(self, c1, c2, layer):        
        q_processed = C.placeholder(shape=(2*self.hidden_dim,))
        p_processed = C.placeholder(shape=(2*self.hidden_dim,))

        qvw, qvw_mask = C.sequence.unpack(q_processed, padding_value=0).outputs

        wq = C.parameter(shape=(2*self.hidden_dim, 2*self.hidden_dim), init=C.glorot_uniform())
        wp = C.parameter(shape=(2*self.hidden_dim, 2*self.hidden_dim), init=C.glorot_uniform())
        wg = C.parameter(shape=(8*self.hidden_dim, 8*self.hidden_dim), init=C.glorot_uniform())
        v = C.parameter(shape=(2*self.hidden_dim, 1), init=C.glorot_uniform())

        # seq[tensor[2d]] p_len x 2d
        wpt = C.reshape(C.times(p_processed, wp), (-1, 2*self.hidden_dim))

        # q_len x 2d
        wqt = C.reshape(C.times(qvw, wq), (-1, 2*self.hidden_dim))
        
        # seq[tensor[q_len]]
        S = C.reshape(C.times(C.tanh(C.sequence.broadcast_as(wqt, p_processed) + wpt), v), (-1))

        qvw_mask_expanded = C.sequence.broadcast_as(qvw_mask, p_processed)

        # seq[tensor[q_len]]
        S = C.element_select(qvw_mask_expanded, S, C.constant(-1e+30))
        
        # seq[tensor[q_len]]
        A = C.softmax(S, axis=0)

        # seq[tensor[2d]]
        swap_qvw = C.swapaxes(qvw)
        cq = C.reshape(C.reduce_sum(A * C.sequence.broadcast_as(swap_qvw, A), axis=1), (-1))

        # seq[tensor[4d]]
        uc_concat = C.splice(p_processed, cq, p_processed * cq, cq * cq)
        
        # seq[tensor[4d]]
        gt = C.tanh(C.times(uc_concat, wg))
        
        # seq[tensor[4d]]
        uc_concat_star = gt * uc_concat
 
        # seq[tensor[4d]]
        vp = C.layers.Sequential([
            C.layers.Dropout(self.dropout),
            OptimizedRnnStack(self.hidden_dim, bidirectional=True, 
                use_cudnn=self.use_cudnn, name=layer+'_attention_rnn')])(uc_concat_star)
        
        return C.as_block(
            vp,
            [(p_processed, c1), (q_processed, c2)],
            'attention_layer_' + layer,
            'attention_layer_' + layer)
        
    def model(self):
        c1_axis = C.Axis.new_unique_dynamic_axis('c1_axis')
        c2_axis = C.Axis.new_unique_dynamic_axis('c2_axis')
        b = C.Axis.default_batch_axis()
        
        c1 = C.input_variable(self.word_dim, dynamic_axes=[b, c1_axis], name='c1')
        c2 = C.input_variable(self.word_dim, dynamic_axes=[b, c2_axis], name='c2')
        
        y = C.input_variable(1, dynamic_axes=[b], name='y')
        
        c1_processed, c2_processed = self.input_layer(c1, c2).outputs
        att_context = self.attention_layer(c2_processed, c1_processed, 'attention')
        
        c2_len = C.layers.Fold(plus1)(c2_processed)
        att_len = C.layers.Fold(plus1)(att_context)
        
        cos = C.cosine_distance(C.sequence.reduce_sum(c2_processed)/c2_len, 
                                C.sequence.reduce_sum(att_context)/att_len)
        
        prob = C.sigmoid(cos)
        is_context = C.greater(prob, 0.5)
        
        loss = C.losses.binary_cross_entropy(prob, y)
        acc = C.equal(is_context, y)
        
        return cos, loss, acc

# %%
"""
Read ctf format to minibatch source, input function
"""
def deserialize(func, ctf_path, model, randomize=True, repeat=True, is_test=False):
    if not is_test:
        mb_source = C.io.MinibatchSource(
            C.io.CTFDeserializer(
                ctf_path,
                C.io.StreamDefs(
                    c1 = C.io.StreamDef('c1', shape=model.word_dim, is_sparse=True),
                    c2 = C.io.StreamDef('c2', shape=model.word_dim, is_sparse=True),
                    y  = C.io.StreamDef('y', shape=1, is_sparse=False))),
            randomize=randomize,
            max_sweeps=C.io.INFINITELY_REPEAT if repeat else 1)

        input_map = {
            argument_by_name(func, 'c1'): mb_source.streams.c1,
            argument_by_name(func, 'c2'): mb_source.streams.c2,
            argument_by_name(func, 'y'): mb_source.streams.y
        }
    else:
        mb_source = C.io.MinibatchSource(
            C.io.CTFDeserializer(
                ctf_path,
                C.io.StreamDefs(
                    c1 = C.io.StreamDef('c1', shape=model.word_dim, is_sparse=True),
                    c2 = C.io.StreamDef('c2', shape=model.word_dim, is_sparse=True))),
            randomize=randomize,
            max_sweeps=C.io.INFINITELY_REPEAT if repeat else 1)

        input_map = {
            argument_by_name(func, 'c1'): mb_source.streams.c1,
            argument_by_name(func, 'c2'): mb_source.streams.c2
        }    
    return mb_source, input_map

# %%
"""
Helper function used to map the variable
"""
def argument_by_name(func, name):
    found = [arg for arg in func.arguments if arg.name == name]
    if len(found) == 0:
        raise ValueError('no matching names in arguments')
    elif len(found) > 1:
        raise ValueError('multiple matching names in arguments')
    else:
        return found[0]

# %%
"""
Trainer
"""
def train():
    model = Model()
    z, loss, acc = model.model()
    
    progress_writers = [C.logging.ProgressPrinter(
                            num_epochs = max_epochs,
                            freq = log_freq,
                            tag = 'Training',
                            log_to_file = 'log/log_' + version)]
    
    lr = C.learning_parameter_schedule(learning_rate, minibatch_size=None, epoch_size=None)
    learner = C.adadelta(z.parameters, lr)
    trainer = C.Trainer(z, (loss, acc), learner, progress_writers)
    
    mb_source, input_map = deserialize(loss, train_data, model)
    mb_valid, valid_map = deserialize(loss, valid_data, model)
    
    try:
        trainer.restore_from_checkpoint('../model/' + version)
    except Exception:
        print('No checkpoint.')
    
    for epoch in range(max_epochs):
        num_seq = 0        
        # validation
        with tqdm_notebook(total=num_validation) as valid_progress_bar:
            while True:
                data = mb_valid.next_minibatch(minibatch_size, input_map=valid_map)
                if not data:
                    break
                trainer.test_minibatch(data)
                num_seq += len(data)
                valid_progress_bar.update(len(data))
                if num_seq >= num_validation:
                    break
            trainer.summarize_test_progress()
            
        num_seq = 0
        # train
        with tqdm_notebook(total=epoch_size) as progress_bar:
            while True:
                data = mb_source.next_minibatch(minibatch_size, input_map=input_map)
                trainer.train_minibatch(data)
                num_seq += trainer.previous_minibatch_sample_count
                progress_bar.update(trainer.previous_minibatch_sample_count)
                if num_seq >= epoch_size:
                    break
            trainer.summarize_training_progress()
            trainer.save_checkpoint('../model/' + version + '/' + str(epoch))

# %%
# train()

# %%
"""
Inference
"""
def inference(data):
    p = Model()
    model = C.load_model('../model/' + version + '/12')

    cos = model.outputs[0]
    loss = C.as_composite(model.outputs[1].owner)

    mb_test, map_test = deserialize(loss, '../data/{}.ctf'.format(data), p, 
                                    randomize=False, repeat=False, is_test=True)
    c1 = argument_by_name(loss, 'c1')
    c2 = argument_by_name(loss, 'c2')

    results = []
    if 'test' in data:
        total_samples = 3000
    else:
        total_samples = num_validation
        
    with tqdm_notebook(total=total_samples) as progress_bar:
        while True:
            data = mb_test.next_minibatch(minibatch_size, input_map=map_test)
            if not data:
                break
            out = model.eval(data, outputs=[cos])
            results.extend(out)
            progress_bar.update(len(data))
    assert(len(results) == total_samples)
    return results

# %%
results = inference(test_data)
# Out:
# HBox(children=(IntProgress(value=0, max=3000), HTML(value='')))

# %%
predict = []
for index in range(0, len(results), 6):
    sample = results[index:index+6]
    predict.append(np.argmax(sample))

# %%
questions = np.load('../data/tokenized_questions.npy')

# %%
for index, p in enumerate(predict):
    print(questions[index][0], questions[index][p + 1])
# Out:
# ['媽', '給你', '送錢', '錢包', '來', '啦', '來', '你', '看', '一下', '是不', '不是', '這', '個', '對', '就是', '這', '個', '你', '在', '哪裡', '找到', '它', '的'] ['早上', '你', '爸爸', '在', '車上', '找到', '的', '一定', '是', '前天', '你', '放學', '的', '時候', '掉', '在', '車上', '了']
# ['古人', '說', '三日', '日不', '讀書', '面目', '面目可憎', '可憎', '我', '覺得', '我', '最近', '可能', '臉色', '太難', '難看', '了'] ['所以', '想', '回復', '我', '昔日', '面貌', '姣好', '的', '樣子']
# ['你', '說', '我們', '做', '父母', '的', '最', '擔心', '的', '就是', '這', '個'] ['只是', '小孩', '自己', '的', '興趣', '不能', '得到', '發展', '他們', '的', '心', '裡', '可能', '也會', '會很', '悶', '喔']
# ['是不', '不是', '因為', '以前', '你', '的', '書包', '太重', '了', '所以', '你', '想要', '發明', '這', '個'] ['這', '個', '應該', '也是', '其', '中', '之', '一', '的', '原因']
# ['那', '可', '不見得', '見得', '有錢', '能', '使', '鬼', '推磨'] ['真的', '嗎', '什', '麼', '禮物']
# ['真的', '嗎', '當然', '是', '真的', '囉', '如果', '你不', '相信', '的', '話', '可以', '問', '姜', '老師', '啊'] ['是', '啊', '這', '點', '老師', '也', '可以', '證明', '喔']
# ['你', '今天', '是要', '介紹', '哪', '一', '位', '人物', '讓我', '我們', '認識', '呢', '是', '和', '戲劇', '有關', '喔', '特別', '是', '默劇'] ['這', '個', '人', '我', '已經', '知道', '是誰', '啦', '就是', '耿', '一', '偉', '老師', '嘛']
# ['輝', '哥', '全', '部', '都', '被', '你', '吃', '了', '你', '很', '過分', '就', '兩', '顆', '你', '還', '剩下', '這樣', '這樣子', '樣子', '那', '我', '吃', '什', '麼', '沒有', '因為', '你們', '一直', '在', '問問', '問題', '我', '閒', '著', '無聊'] ['我就', '把', '它', '吃完', '了']
# ['大嬸', '啊', '我不', '不是', '說', '過了', '嗎', '我們', '村子', '都是', '善男信女', '老弱', '老弱婦孺', '婦孺', '怎麼', '會', '是', '練功', '的', '料', '呢'] ['我們', '讀', '不', '讀書', '關', '你', '屁事', '啊', '你', '管', '那麼', '那麼多', '幹嘛']
# ['你', '只要', '拿得到', '得到', '滅火', '滅火器', '火器', '就', '代表', '你', '的', '逃生', '生動', '動線', '是', '安全', '的', '你', '就算', '火滅', '滅不', '掉'] ['你', '還是', '可以', '跑出', '跑出去', '出去']
# ['你不', '不知', '知道', '那', '些', '狗仔', '什', '麼', '時候', '又', '跑去', '挖', '你', '那', '間', '舊房', '房子', '的', '新聞'] ['如果', '有', '工作', '後', '的', '學長', '姐', '分享', '享會', '會更', '棒']
# ['那你', '覺得', '應該', '收', '多', '少', '錢', '才', '好', '大家', '同學', '嘛', '也不', '不能', '太貴', '一', '次', '二', '十', '怎麼', '怎麼樣', '薄利多銷', '利多', '銷'] ['上', '次', '我不', '不是', '跟', '你', '說', '這', '個', '秘密', '基地', '漏水', '的', '事情', '嗎']
# ['你', '最', '拿手', '的', '是', '什', '麼', '菜'] ['炒高', '高麗', '高麗菜']
# ['奕瑄', '我知', '知道', '你', '很', '生氣', '但', '你先', '看看', '卡片', '裡面', '寫', '些', '什', '麼', '內容', '好', '嗎', '奕瑄', '芷', '穎', '都', '這樣', '這樣子', '樣子', '了', '你', '就', '原諒', '他', '嘛'] ['對', '啊', '芷', '穎', '都', '知道', '錯', '了', '你', '就', '原諒', '他', '吧']
# ['其實', '你', '可以', '試著', '把', '你', '最近', '感覺', '感覺到', '的', '還', '有', '想到', '的', '把', '它', '寫下', '寫下來', '下來'] ['你', '還要', '當', '著', '全', '班', '的', '面', '朗讀', '她', '當然', '會', '覺得', '很難', '難堪']
# ['我們', '集訓', '兩', '個月', '之後', '然後', '僥倖', '得到', '冠軍', '什', '麼', '僥倖', '得到', '冠軍'] ['真的', '僥倖', '啦']
# ['上面', '怎麼', '有', '刮痕', '哪', '有', '本來', '就', '這樣', '啊'] ['明明', '就有', '你', '自己', '看']
# ['請你', '當', '我', '女朋友', '朋友', '我', '我', '覺得', '跟', '你', '在一起', '一起', '很開', '開心', '但是', '我們', '還是', '繼續', '當', '好', '同學', '就好', '好了'] ['我', '真', '不懂', '為什麼', '詠', '真一', '一下', '跟', '我', '說', '在一起', '一起', '很開', '開心', '一下', '又', '說', '當', '好', '同學', '就好']
# ['說', '台灣', '每年', '大概', '有', '四', '千人', '因為', '自殺', '而', '身亡', '呢', '光', '聽', '我就', '起', '雞皮', '雞皮疙瘩', '疙瘩', '了', '耶'] ['四', '千', '條', '生命', '就', '這麼', '因為', '想不開', '而', '沒', '了', '喔']
# ['奕瑄', '你', '怎麼', '了', '媽', '你', '可不可以', '不可', '不可以', '可以', '叫', '爸', '不要', '再', '來', '學校', '接', '我', '啦', '可是', '是你', '以前', '前不', '不是', '都', '吵', '著', '要', '爸爸', '去', '學校', '接', '你', '嗎'] ['直接', '接送', '訓導', '訓導處', '去處', '處理', '就好', '啦']
# ['你不', '不要', '生氣', '嘛', '媽媽', '只是', '替', '你', '跟', '謝秀', '秀菁', '把', '事情', '說清', '說清楚', '清楚', '而已'] ['不過', '我', '真的', '沒有', '惡意', '喔', '我不', '不是', '是來', '興師問罪', '問罪', '的']
# ['你', '現在', '在在', '選', '什', '麼', '魚'] ['我', '在', '選', '狗', '母魚']
# ['我', '工作', '工作服', '穿好', '好了', '以後', '要', '開始', '怎麼', '做', '呢', '開始', '我們', '今天', '要', '做', '的', '是', '對稱', '什', '麼', '叫', '對稱'] ['要', '開始', '怎麼', '做', '呢']
# ['那', '不是', '鹽', '啦', '原來', '是', '這樣', '喔', '來', '我', '再', '跟', '你', '解釋', '一下'] ['就是', '那', '個', '曬鹽', '的', '地方', '喔']
# ['對不起', '不好', '不好意思', '好意', '好意思', '意思', '我剛', '剛才', '叫', '你', '番茄'] ['其實', '我', '也', '說錯', '了']
# ['我們', '現在', '就要', '每五分鐘', '五分鐘', '分鐘', '做', '一', '次', '記錄', '看看', '哪', '一', '鍋', '的', '蝦子', '最先', '死', '翹翹'] ['對', '然後', '這樣', '就能', '知道', '牠們', '到底', '在', '尿液', '能不能', '不能', '不能夠', '能夠', '存活', '比較', '久']
# ['那', '如果', '我', '考', '不', '上', '難道', '你', '也要', '配合', '嗎', '這是', '什', '麼', '話', '我', '對', '你', '有', '信心'] ['你', '都', '對', '自己', '沒', '信心', '了']
# ['我', '先生', '那時', '時候', '常常', '喝', '酒'] ['我', '常', '勸', '他不', '不要', '喝', '了']
# ['因為', '我二', '十', '歲', '就', '結婚', '了'] ['結婚', '以後', '後生', '了', '兩', '個', '孩子']
# ['你', '的', '水', '是要', '倒掉', '的', '嗎', '對', '啊'] ['這', '飲料', '真', '好喝']
# ['你', '看', '這天', '你', '根本', '沒有', '寫', '說', '要', '帶', '英文', '作業', '嘛', '還', '說', '有', '寫'] ['以後', '沒有', '交', '作業', '只要', '這樣', '應', '一', '聲', '就', '可以', '打混', '過去', '了']
# ['依', '你', '的', '經驗', '來', '看', '蝦子', '是不', '不是', '比較', '適合', '活', '在', '海水', '水裡'] ['是', '啊', '牠', '本來', '就', '在', '海洋', '裡面', '所以', '牠', '應該', '在', '海水', '水裡', '裡面', '是', '最', '健康', '的']
# ['來', '媽', '剛', '打好', '的', '新鮮', '鮮果', '果菜', '果菜汁', '菜汁', '休息', '一下', '嘛', '一直', '直盯', '著', '課本', '會', '傷眼', '眼睛', '的', '喔', '好', '啦', '放', '在', '桌子', '上', '我等', '等一下', '一下', '就', '喝'] ['趕快', '趁', '鮮', '喝', '要不', '要不然', '不然', '維他命', 'C', '就', '流失', '啦']
# ['洪老', '老師', '您好', '是不', '不是', '只有', '澎湖', '的', '赤崁', '才', '有', '丁香', '丁香魚', '香魚', '別', '的', '地方', '沒有'] ['其實', '這', '個', '丁香', '丁香魚', '香魚', '台灣', '沿海', '四周', '都有', '產']
# ['老師', '為什麼', '他們', '都有', '有我', '我沒', '沒有'] ['潘', '依宸', '跟', '同學', '他們', '相處', '的', '情形']
# ['剛剛', '珠珠', '說', '你是', '依', '君', '的', '祕書'] ['那', '位大', '大小', '大小姐', '小姐', '幹嘛', '給你', '巧克力']
# ['如果', '哪', '一', '個', '轉身', '他沒', '沒有', '轉過', '轉過去', '過去', '了', '他', '就是', '會', '走到', '今天', '了', '是', '而', '在', '老師', '的', '戲', '裡面', '我', '覺得', '你是', '在', '關心', '這', '些', '人', '他們', '看到', '了', '這', '些', '片段', '的', '時候'] ['是', '這', '個', '是我', '覺得', '很棒', '的', '一', '件', '事']
# ['總教練', '教練', '耶', '看起來', '起來', '好年', '年輕', '喔', '我一', '一直', '以為', '練', '太極', '太極拳', '的', '都是', '那', '種', '白髮', '蒼蒼', '的', '老公', '老公公', '公公', '耶'] ['其實', '練', '太極', '太極拳', '不管', '他', '的', '年齡', '高矮', '矮胖', '胖瘦', '都是', '可以', '習練', '的']
# ['想法', '奇特', '的', '他', '會', '想', '邀請', '的', '來賓', '是誰', '呢'] ['張秀卿', '她', '的', '歌', '真的', '很好', '好聽']
# ['而且', '福馬', '福馬林', '馬林', '聽說', '有一', '種', '很', '奇怪', '的', '味道', '我剛', '剛剛', '剛也', '有', '聞到', '你', '幫', '我', '聞聞', '聞聞看', '怎麼', '怎麼樣', '感覺', '有一', '種', '化學', '刺激', '味', '聞起來', '起來', '讓人', '很不', '舒服'] ['不', '舒服', '的', '感覺', '嗎']
# ['你們', '怎麼', '會', '在', '這裡'] ['是你', '自己', '跳到', '我們', '旁邊', '來', '的']
# ['你', '怎麼', '可能', '會', '聽', '古典', '音樂', '拜託', '我', '也是', '很有', '氣質', '的'] ['你', '這樣', '這樣子', '樣子', '很難', '讓我', '相信', '你', '有', '氣質']
# ['我', '發現', '你們', '這邊', '有', '兩', '棵', '這麼', '大', '棵', '的', '鐵樹', '啊', '這', '個', '應該', '也是', '歷史', '悠久', '了', '從', '什', '麼', '時候', '開始', '啊'] ['照', '我', '的', '估計', '它', '大概', '有一', '百', '三', '十', '歲', '左右']
# ['你們', '現在', '要', '做', '什', '麼'] ['我們', '現在', '把', '網子', '給', '拉開', '來']
# ['要是', '是有', '什', '麼', '事情', '我', '幫', '你', '出面', '解決', '嘛', '你', '還要', '管', '我', '嗎', '你', '已經', '幫倒忙', '了', '你不', '不要', '這麼', '說', '嘛', '媽媽', '又', '不是', '是一', '個', '沒有', '腦袋', '的', '人'] ['你', '的', '腦袋', '就是', '跟', '別人', '想', '的', '不一', '一樣']
# ['家', '隆', '你', '怎麼', '會', '在', '這', '個', '地方', '因為', '這', '棟', '房子', '很', '可愛', '引發', '了', '我', '的', '好奇', '好奇心', '所以', '就', '進來', '參觀', '了', '是', '露營', '露營車', '的', '主人', '請你', '進來', '的', '嗎'] ['沒錯', '因為', '我就', '一直', '好奇', '的', '張望', '於是', '露營', '露營車', '的', '主人', '就', '請', '我', '進來', '參觀', '了']
# ['阿公', '要', '離開', '開台', '台灣', '了'] ['但', '在', '這', '群', '人手', '上', '鏟子', '只有', '有一', '種', '用法']
# ['我', '媽', '說', '這', '個', '老年', '老年人', '老人', '老人家', '人家', '最', '經不起', '這樣', '摔', '的', '啦', '很', '危險', '啊', '你', '現在', '在在', '說', '什', '麼'] ['你', '說', '誰', '是', '老年', '老年人']
# ['大家', '幫', '你', '送行', '你', '自己', '跑來', '在', '這裡', '我', '都', '快', '被', '安安', '煩死'] ['你別', '無聊', '了', '好不', '好不好', '不好']
# ['希望', '我', '哪天', '可以', '跟', '她', '一樣', '說', '英文', '都不', '不會', '緊張', '英文', '是', '說', '得', '很好', '啦'] ['包準', '你', '聽', '了', '會', '開心', '很多', '的']
# ['你', '在', '幹嘛', '怎麼', '突然', '停下', '停下來', '下來', '了', '沒有', '啦', '剛好', '放空'] ['你', '在', '那', '兩', '分鐘', '的', '獨奏', '奏表', '表演']
# ['這', '個', '牛山', '山保', '保護', '保護區', '這邊', '海岸', '海岸線', '岸線', '又', '特別', '的', '長', '沙', '跟', '鵝卵石', '卵石', '特別', '的', '多', '所以', '這', '種', '換膚', '的', '情況'] ['就', '特別', '的', '明顯']
# ['我是', '劉', '亮', '宏', '我', '對', '化學', '中', '的', '奈米', '科技', '很', '感興趣', '興趣'] ['我是', '蕭年', '艾', '科學', '對', '我來', '說', '是一', '個', '可以', '滿足', '我好', '好奇', '好奇心', '的', '領域']
# ['鍾', '沅', '幹嘛'] ['我有', '話', '要', '跟', '你', '講']
# ['新年', '快', '到', '了', '曉', '書', '你', '過年', '有沒有', '沒有', '什', '麼', '計劃', '呢'] ['我', '打算', '回', '高雄', '的', '老家', '全', '家', '團圓', '吃', '年夜', '年夜飯', '夜飯']
# ['借', '我', '你', '的', '百發百中', '重點', '筆記', '好不', '好不好', '不好', '不好'] ['拜託', '啦', '你', '如果', '借', '我', '的', '話', '下', '次要', '我', '做', '什', '麼', '事情', '我', '都可', '可以', '幫', '你']
# ['賢賢', '走', '我們', '去', '放', '好', '啊', '等一下', '一下'] ['豆油', '豆油伯', '星期', '星期天', '你', '一定', '要', '來', '捧場']
# ['這', '種', '廣告', '能', '把', '房子', '賣出', '賣出去', '出去', '才', '有鬼', '哪', '個', '白癡', '哪', '個', '腦殘', '想', '的', '該不', '不會', '是你', '吧', '啊', '報告', '賀', '總', '我', '最近', '太忙', '了', '只好', '請', '新人', '幫忙', '所以', '真正', '想', '廣告', '廣告詞', '的', '是', '她'] ['這', '三', '個', '字', '也是', '是我', '我們', '賀', '氏', '房屋', '的', '精神', '指標']
# ['等一下', '一下', '我就', '回去', '接', '你', '跟', '你媽', '媽媽', '今天', '我們', '全', '家', '一起', '去', '吃', '大餐'] ['明天', '你', '要去', '比賽']
# ['那', '你', '會', '說', '台語', '嗎'] ['我會', '啊']
# ['好', '快', '喔', '一', '個月', '又', '過去', '了', '是', '啊', '所以', '我們', '要好', '好好', '的', '把握', '時間', '啊', '對', '啊'] ['不然', '又', '多', '一', '歲', '囉']
# ['你', '說', '的', '這', '位', '視障', '豎笛', '高手', '是', '哪', '位', '啊'] ['這', '位', '豎笛', '高手', '的', '名字', '叫做', '胡', '清', '祥']
# ['老師', '你先', '回去', '好了', '我一', '個', '人', '可以', '照顧', '爸爸', '的'] ['子', '寧', '我還', '還是', '留下', '留下來', '下來', '再', '陪', '你', '一會', '一會兒', '會兒', '好了']
# ['是', '什', '麼', '因素', '會讓', '你', '接觸', '接觸到', '觸到', '藝術', '方面', '呢', '為什麼'] ['其實', '實是', '是有', '有一', '些', '巧合', '啦', '那', '當然', '我', '小時', '小時候', '時候', '很', '喜歡', '戲劇']
# ['要不', '要不要', '不要', '吃飯', '我', '幫', '你', '買'] ['人家', '不是', '是不', '不讓', '你', '處理']
# ['老師', '要不', '要不要', '不要', '再', '重新', '考慮', '一下', '有', '什', '麼', '不好', '的', '人家', '姵', '蓁', '很', '可愛', '做', '事', '又', '負責', '對', '啊', '人家', '老師', '才', '不', '像', '你們', '男生', '只會', '看', '外表', '一點', '都不', '不成', '成熟'] ['好', '啊', '那你', '說', '你們', '有', '祐', '禎', '的', '漂亮', '和', '溫柔', '嗎']
# ['幫助', '珮', '綺', '在', '班上', '同學', '面前', '前建', '建立', '自信', '自信心', '信心', '這樣', '才是', '將功贖罪', '贖罪', '啊'] ['你', '願不願', '願不願意', '不願', '願意', '回到', '到班', '班上']
# ['不過', '這', '個', '本', '氏', '液', '是', '幹嘛', '用', '的', '你不', '不知', '知道', '喔', '來', '小中', '解釋', '解釋給', '給他', '聽'] ['沒', '問題', '看', '我', '的', '秘密', '檔案', '本', '氏', '液', '它', '是藍', '藍色', '的', '液體']
# ['他', '的', '名字', '好像', '叫做', '陳', '明偉', '對', '不對'] ['一起', '起來', '欣賞', '陳', '明偉', '的', '表演', '囉']
# ['打', '了', '三', '十', '六', '圈', '的', '牌', '一', '天一', '一夜', '都沒', '闔眼', '了', '不錯', '嘛', '你', '還', '記得', '我們', '的', '門牌', '門牌號', '牌號', '號碼', '喔', '我', '以為', '你', '迷', '了', '路', '找', '不', '到', '家', '了', '你', '煩', '不', '煩', '啊', '一', '進門', '就', '唸', '我', '看', '你是', '睡飽', '了'] ['你', '還好', '好意', '好意思', '意思', '對', '我', '大聲', '啊', '你', '看看', '現在', '幾點鐘', '點鐘', '了']
# ['你們', '兩', '個', '會不會', '不會', '太', '誇張', '了一', '一點', '隨時', '隨地', '都', '看到', '你們', '黏', '在一起', '一起', '我', '跟', '珺', '嵐', '這麼', '有', '默契', '借到', '的', '東西', '也', '一模一樣', '一樣', '這樣', '會', '被', '誤會', '誰', '跟', '你', '有', '默契'] ['是', '舒', '琪', '千', '晏', '她們', '有', '默契']
# ['蘿拉', '跟', '幼華', '進行', '語言', '交換', '活動', '三年', '多', '了', '每', '次', '碰面', '幼華', '都很', '認真', '準備', '資料'] ['接著', '牛爾', '問起', '兩', '個', '孩子']
# ['好', '裝好', '好了', '綁腿', '之後', '呢', '我們', '還要', '上', '這', '個', '汗', '墊', '汗', '墊', '汗', '墊', '是', '幹嘛', '的'] ['汗', '墊', '就是', '防止', '它', '在', '馬背', '上', '的', '時候', '會', '因為', '汗', '而', '這樣', '滑來', '滑', '去']
# ['我們', '有', '問題', '要', '問', '你', '可是', '老師', '現在', '有事', '事情', '耶'] ['我們', '下', '次', '再', '問好', '好了']
# ['你', '曾', '聽說', '過', '你們', '這裡', '有一', '種', '怪', '水', '嗎'] ['怪', '水', '什', '麼', '怪', '水']
# ['那你', '有', '什', '麼', '新發', '發現', '嗎', '我', '發現', '其實', '芳', '儀', '不是', '那麼', '的', '嬌弱', '以後', '我不', '不能', '再', '把', '她', '當', '溫室', '的', '花朵', '了'] ['媽媽', '有', '跟', '老師', '說', '她正', '正在', '嘗試', '改變', '她', '自己']
# ['曉', '書', '你', '在', '做', '什', '麼', '啦', '你', '你', '幹嘛', '那麼', '緊張', '呢'] ['我只', '只是', '在', '跟', '重車', '拍張照', '張照']
# ['今天', '要', '介紹', '一', '位', '藝術', '藝術家', '朋友', '她', '可是', '鼎鼎有名', '有名', '獲獎', '無', '數', '的', '足', '畫家', '喔', '原來', '原來如此', '如此', '啊'] ['待會', '待會兒', '會兒', '就', '可以', '欣賞', '欣賞到', '許多', '國畫', '畫作', '作品']
# ['家裡', '的', '生意', '正在', '忙', '需要', '你', '不要', '一直', '想要', '跑到', '外面', '去', '玩', '好不', '好不好', '不好'] ['我不', '不是', '是要', '出去', '玩', '我是', '是要', '要去', '學', '更多', '的', '東西']
# ['怎麼', '才', '幾', '天', '不', '見', '你', '的', '眼睛', '就', '變成', '成熊', '熊貓', '貓眼', '了'] ['美白', '白面', '面膜', '讓', '你', '閃閃', '閃動', '動人']
# ['媽', '我', '的', '手', '好痛', '我不', '不能', '彈琴', '了', '啦', '怎麼', '會', '這樣', '這樣子', '樣子', '呢'] ['要', '幫', '我', '姐姐', '演奏', '的', '婚禮', '歌曲']
# ['他', '活該', '倒楣', '手錶', '壞', '了', '你', '幹嘛', '幫', '他', '修', '可是', '如果', '我沒', '追', '他', '的', '話', '他', '的', '錶', '應該', '就', '不會', '掉', '吧'] ['那是', '他', '活該']
# ['黃', '媽媽', '那是', '是你', '種', '的', '圓葉', '椒', '草', '嗎', '你', '也', '懂得', '圓葉', '椒', '草', '一般', '一般人', '只', '懂得', '它', '是', '盆栽'] ['當然', '囉', '因為', '我們', '家', '也', '有種', '而且', '我', '也', '蠻', '喜歡', '植物', '的']
# ['不過', '現在', '海上', '上風', '風平浪靜', '的', '好', '舒服', '喔'] ['是', '啊', '沒', '什', '麼', '浪', '對', '不對']
# ['不要', '說', '功課', '沒人', '管', '我', '看', '飯', '也沒', '沒得', '吃', '你', '講話', '憑', '良心', '喔', '你', '問', '碧', '珊', '我是', '餓', '著', '她', '還是', '凍', '著', '她', '了'] ['講', '我', '你', '自己', '呢', '整天', '整', '夜', '的', '不', '在', '家']
# ['因為', '吊白', '白塊', '裡面', '有一', '種', '成分', '叫做', '福馬', '福馬林', '馬林', '同學', '們', '知道', '福馬', '福馬林', '馬林', '是', '什', '麼', '嗎', '用來', '做', '標本', '用', '的'] ['你好', '聰明', '喔']
# ['您', '知道', '他們', '在', '做', '什', '麼', '呢', '在', '釣魚', '其實', '實是', '釣', '小', '管'] ['釣', '得到', '嗎']
# ['考', '得', '不錯', '嘛', '竟然', '考', '八', '十', '七', '分'] ['補習', '補習班', '怎麼', '那麼', '小']
# ['聽說', '你', '以前', '最重', '的', '時候', '有一', '百', '五', '十', '公斤', '啊', '是', '什', '麼', '情況', '去', '了', '美國', '之後', '的', '一', '兩', '年', '之內', '我', '的', '食量', '大增', '吃', '多', '又', '懶得', '得運', '運動'] ['難怪', '體重', '會', '這麼', '重']
# ['這', '哪', '叫做', '算命', '啊', '你們', '這', '些', '人', '啊', '真是', '太', '好', '騙', '了', '那', '什', '麼', '才', '叫', '真的', '算命', '呢'] ['算', '八字', '啦', '測字', '啊', '卜', '卦', '啊', '還', '有紫', '紫微', '紫微斗數', '啊']
# ['你', '會', '覺得', '我們', '很怪', '嗎'] ['不會', '啊', '我', '覺得', '你們', '很', '自由']
# ['豆油', '豆油伯', '你不', '不要', '生氣', '啦', '小兵', '沒有', '這', '個', '意思', '啦', '我們', '這', '個', '村子', '大家', '都', '知道', '你', '做人', '最好', '還', '有', '童叟', '童叟無欺', '無欺'] ['對', '啊', '你', '才', '知道', '啊']
# ['阿伯', '你', '這', '池裡', '裡面', '有', '養', '什', '麼', '東西'] ['豆仔', '豆仔魚', '仔魚', '花', '身', '仔', '還', '有', '蝦子', '混養', '的', '啦']
# ['而', '對於', '製作', '作手', '手工', '娃娃', '來', '說', '一', '雙', '靈活', '又', '生動', '的', '眼睛'] ['同樣', '也是', '作品', '成敗', '的', '關鍵']
# ['弄', '這麼', '高', '牠', '大概', '也', '跳', '不', '出去', '啦', '那', '跳出', '出去', '了', '怎麼', '怎麼辦', '呢'] ['跳出', '出去', '就', '讓', '牠', '放生', '囉']
# ['其實', '奕瑄', '這樣', '的', '心態', '是', '可以', '被', '理解', '的', '可是', '是我', '先生', '他', '已經', '經痛', '痛改前非', '了', '啊'] ['我', '認為', '為要', '讓', '奕瑄', '重新', '打開', '開心', '心房', '是', '急不得', '不得', '的', '我們', '需要', '更多', '的', '毅力', '跟', '耐性']
# ['媽媽', '我', '跟', '你', '講', '上', '次', '那', '個案', '案子', '明天', '就要', '正式', '發包', '包出', '出去', '了'] ['真的', '啊', '真', '應該', '去', '慶祝', '一下']
# ['你知', '知道', '高雄', '的', '舊名', '名叫', '打狗', '嗎', '這', '個', '不是', '基本', '常識', '嗎', '那你', '你知', '知道', '我', '現在', '站', '的', '地方', '其實', '實是', '海', '嗎'] ['其實', '這裡', '大家', '很多', '不', '曉得']
# ['媽', '以為', '你是', '是一', '一時', '時興', '興起', '沒想到', '想到', '你', '越', '做', '越', '開心', '你', '想', '不', '想', '朝', '這', '方面', '的', '興趣', '發展', '可是', '可以', '嗎'] ['當然', '可以', '啦', '你', '只要', '選擇', '你', '所', '愛愛', '愛你', '所', '選']
# ['哥哥', '你', '想', '邀請', '誰來', '來家', '家裡', '跟', '你', '吃飯'] ['我', '想', '邀請', '乾爸']
# ['她', '可', '不只', '只是', '叩', '來', '長相', '一樣', '的', '依依', '彼此', '還', '互換', '換衣', '衣服', '交換', '身上', '的', '氣味', '這', '招', '還', '真', '絕'] ['我們', '兩', '個', '換', '了', '衣服', '了', '耶']
# ['奇怪', '是', '走', '這', '條', '路', '沒錯', '啊', '怎麼', '會', '來到', '什', '麼', '小烏來', '烏來', '風景', '風景區', '景區'] ['這麼', '久', '不', '見', '你', '看起來', '起來', '更', '魁梧']
# ['這', '中間', '他', '都', '感覺', '不', '到', '你', '對', '他', '的', '好感', '嗎', '沒有', '我很', '很會', '藏', '他', '幫', '你', '這麼', '這麼多'] ['其實', '實說', '說不定', '不定', '他也', '有點', '喜歡', '你', '呢']
# ['豆油', '豆油伯', '我', '跟', '你', '講', '喔', '我們', '禮拜', '禮拜天', '要', '辦成', '成果', '發表', '發表會', '你', '一定', '要', '來', '喔', '要', '我', '去', '喔'] ['豆油', '豆油伯', '星期', '星期天', '你', '一定', '要', '來', '捧場']
# ['你', '看', '他們', '的', '婚姻', '你', '覺得', '好', '嗎'] ['即使', '如此', '自己', '是', '男', '同志', '的', '事', '也', '從', '沒', '跟', '媽媽', '說']
# ['這', '什', '麼', '東西', '銅鑼', '銅鑼燒', '你是', '哆', '啦', 'A', '夢', '對', '不對'] ['因為', '哆', '啦', 'A', '夢', '最', '喜歡', '吃', '銅鑼', '銅鑼燒', '了']
# ['好', '熱鬧', '喔', '看到', '他們', '這麼', '熱情', '的', '招待', '我', '知道', '我要', '來', '這麼', '大', '的', '場面', '來', '歡迎', '我'] ['真是', '是有', '有點', '不好', '不好意思', '好意', '好意思', '意思']
# ['那', '我們', '東邊', '升起', '的', '這一', '票', '星座', '呢', '我們', '就', '叫做', '冬季', '星空', '那是', '是不', '不是', '頭頂', '頂上', '還', '有', '星座', '對', '不對'] ['那就', '就是', '前', '一', '個', '季節', '的', '星座']
# ['這', '個', '扁柏', '館', '也是', '用', '扁柏', '蓋', '的', '啊'] ['不是', '我們', '是', '用', '紙', '蓋', '的', '喔']
# ['你們', '種', '在', '這邊', '的', '話', '它', '的', '那', '個', '根', '都會', '到', '水裡', '所以', '魚', '的', '卵', '都', '產', '在', '那', '個', '根', '上面', '對', '鄭', '叔叔', '說'] ['這裡', '的', '魚', '繁殖', '方式', '非常', '的', '特別']
# ['你', '會', '留在', '這裡', '嗎', '我不', '不知', '知道'] ['那', '我', '跟', '你', '一起', '回', '漁港', '好了']
# ['天氣', '這麼', '熱', '你', '還會', '感冒', '哈啾', '哈啾', '才', '不是', '感冒', '咧', '可能', '是你', '那', '個', '被子'] ['害', '我', '鼻子', '現在', '過敏']
# ['跟', '我', '濂', '僑', '一起', '妙手', '走', '天下', '絕對', '對錯', '錯不了', '不了', '那你', '能不能', '不能', '安排', '一趟', '果園', '之', '旅', '呢', '今天', '就要', '介紹', '一', '個', '可以', '享受', '採果', '果樂', '樂趣', '的', '農園'] ['是', '什', '麼', '樣', '的', '農園', '呢']
# ['請', '鄭', '組長', '來', '說', '一', '說', '公部', '公部門', '部門', '為了', '推行', '無', '障礙', '環', '做', '了', '哪', '些', '事情', '呢', '我們', '們大', '大概', '第', '一', '個', '就是'] ['我們', '依照', '身心', '身心障', '心障', '障礙', '保護', '保護法', '護法', '法第', '五', '十', '六', '條']
# ['考試', '交白卷', '白卷', '這樣', '叫', '誠實', '啊', '你', '有沒有', '沒有', '羞恥', '羞恥心', '啊', '不然', '你', '要', '我', '怎麼', '怎麼樣', '作弊', '你', '會', '比較', '高興', '嗎', '這是', '是你', '跟', '老師', '說話', '的', '態度', '嗎', '一點', '家教', '都沒', '沒有'] ['好', '現在', '跟', '著', '老師', '呢', '把', '這一', '課', '的', '課文', '念', '一遍']
# ['總算', '考完', '了', '還好', '你', '臨時', '幫', '我', '惡補', '我', '這', '次', '寫', '得', '非常', '順', '你', '怎麼', '啦', '你', '應該', '考', '得', '很好', '吧'] ['我', '在', '想', '如果', '那天', '我沒', '沒有', '傳', '紙條', '給你', '今天', '就', '不用', '再', '考', '一', '次', '了']
# ['不知', '知道', '有沒有', '沒有', '有興', '興趣', '在', '演藝', '演藝圈', '發展', '我', '當然', '有興', '興趣', '啊', '不過', '我是', '是一', '個', '很有', '有原', '原則', '的', '人'] ['我是', '覺得', '做', '明星', '沒有', '那麼', '容易']
# ['豆油', '豆油伯', '你', '怎麼', '有', '那麼', '那麼多', '錢', '你', '在', '藏私', '私房', '私房錢', '房錢', '對', '不對'] ['沒有', '這不', '不是', '私房', '私房錢', '房錢', '這', '本來', '就是', '是要', '拿去', '郵局', '存', '的']
# ['誰', '叫', '你是', '瘋狂', '百', '米', '小兵', '啊', '這', '種', '要', '體力', '要', '速度', '的', '當然', '是要', '你', '啊', '我剛', '剛剛', '在', '拿', '這', '個', '麥克', '麥克風', '到處', '廣播', '的', '時候', '啊', '我', '覺得', '這樣', '做', '實在', '是', '很', '沒有', '有效', '有效率', '效率', '耶'] ['對', '啊', '這', '應該', '該不', '大可', '可能', '吧']
# ['我', '做錯', '什', '麼', '為什麼', '要', '這樣', '對', '我', '羽', '君', '剛才', '一定', '是個', '誤會', '大家', '家解', '解釋', '釋清', '清楚', '就', '沒事', '了', '你不', '不要', '難過', '嘛'] ['這不', '不是', '誤會', '是', '歧視', '是', '成見']
# ['阿嬤', '你', '現在', '要去', '哪裡', '要去', '樓上', '啊', '要去', '做', '什', '麼'] ['廟裡', '的', '人形', '形容', '阿嬤', '是', '獨行', '獨行俠']
# ['聽說', '你們', '兩', '個', '很', '厲害', '有', '那', '種', '很酷', '的', '發明', '還好', '啦', '但是', '發明', '倒是', '是有', '滿', '地', '都是'] ['那', '跟', '我們', '們分', '分享', '一下', '吧']
# ['輝', '哥', '你', '幫', '我', '看', '一下', '我', '做', '的', '這', '張', '海報', '怎麼', '怎麼樣', '地點', '跟', '時間', '都很', '清楚', '內容', '也', '蠻', '豐富', '的', '可是'] ['如果', '可以', '把', '我們', '這', '個', '下課', '花', '路', '米', '的', '隊徽', '加上', '加上去', '上去', '的', '話', '我', '覺得', '這樣', '會更', '更好', '一點']
# ['卻', '選擇', '在', '不', '到', '三', '十', '歲', '的', '時候', '拋棄', '了', '自己', '的', '家庭', '當時', '他', '的', '兩', '個小', '小孩', '都不', '到', '五', '歲', '我是', '被', '逼', '的', '啊'] ['我是', '被', '我', '的', '父母', '逼', '的']
# ['臉上', '就', '明明', '寫', '著不', '開心', '你', '到底', '怎麼', '了', '嗎', '你', '要', '我', '講', '什', '麼', '我就', '就是', '是不', '開心', '不', '開心', '也', '總', '有', '個', '原因', '你', '就', '告訴', '媽媽'] ['講', '有', '什', '麼', '用', '說不定', '不定', '還', '被', '你', '唸']
# ['他只', '只是', '是個', '沉迷', '嘻哈', '音樂', '的', '少年', '一', '聽到', '嘻哈', '音樂', '就', '忍不住', '想', '跳舞'] ['一', '跳舞', '身體', '就', '停', '不下', '下來']
# ['哦', '妳', '還', '在', '生氣', '喔', '好', '啦', '以後', '我不', '不去', '了', '啦', '當初', '媒人', '說', '你不', '喝', '不', '賭', '我', '以為', '你是', '可以', '讓我', '依靠', '一輩子', '輩子', '的', '人'] ['好', '啦', '好', '啦', '不然', '我', '發誓', '我', '絕對', '不再', '賭', '了']
# ['楊', '伯伯', '你們', '對', '淑', '怡', '的', '未來', '有', '什', '麼', '打算', '沒有', '這樣', '呢', '我們', '就是', '希望', '她', '的', '畫藝', '藝能', '能夠', '更', '進步'] ['我們', '希望', '說', '也', '趕快', '把', '它', '改過', '改過來', '過來']
# ['小兵', '哥哥', '你', '要不', '要不要', '不要', '綁綁', '看', '我', '可以', '綁', '是不', '不是'] ['可以', '啊']
# ['我', '覺得', '我', '什', '麼', '事情', '都', '做', '不好', '常常', '都', '惹', '同學', '學生', '生氣', '怎麼', '會', '呢'] ['我', '每', '次', '都', '想', '做好', '可是', '常常', '出錯', '同學', '都不', '喜歡', '我']
# ['警察', '叔叔', '你', '拿', '這是', '什', '麼'] ['是', '新', '的', '東里', '火車', '火車站', '車站']
# ['你', '有', '買', '零食', '喔', '那', '我', '也要', '吃'] ['不行', '啦', '這', '個', '是我', '下禮', '禮拜', '去', '露營', '要', '帶', '的']
# ['那你', '從', '幾', '歲', '的', '時候', '開始', '在學', '做', '打鐵'] ['初級', '中學', '畢業', '就', '開始', '做']
# ['小', '光', '來', '爸', '餵', '你', '海', '生', '仔', '你', '這樣', '在', '幹什麼', '餵', '小孩', '讓', '阿蘭', '餵', '就好'] ['吃飯', '皇帝', '帝大', '你', '站起', '站起來', '起來', '幹嘛']
# ['很', '討厭', '耶', '那麼', '甜蜜', '幹嘛', '你', '嫉妒', '人家', '喔'] ['我', '才', '不是', '嫉妒', '呢']
# ['那你', '為什麼', '喜歡', '來', '這裡'] ['這', '群', '可愛', '的', '小朋友', '朋友', '就是', '阿嬤', '的', '寶貝', '孫']
# ['你', '什', '麼', '星座', '射手', '你', '呢'] ['我不', '不見得', '見得', '得知', '知道']
# ['我', '爸爸', '很', '喜歡', '一邊', '看', '電視', '一邊', '挖', '鼻孔'] ['髒', '死', '了', '你', '爸', '真的', '都', '這樣', '做', '喔']
# ['我不', '想', '讓', '同學', '知道', '我', '爸爸', '坐', '過', '牢', '很', '丟臉', '耶', '奕瑄', '你', '怎麼', '可以', '這樣', '講話', '這樣', '很', '沒有', '有禮', '禮貌', '耶'] ['這', '可是', '公共', '場合', '喔', '你', '可', '不要', '讓他', '他們', '再', '相互', '餵食', '喔', '這', '很', '沒', '禮貌', '的']
# ['請問', '鍾', '沅', '搬走', '了', '嗎', '對', '呀'] ['失去', '鍾', '沅', '的', '那一', '那一年', '一年', '我', '幾乎', '崩潰']
# ['你', '做', '這', '陶土', '做多', '多久', '啦', '怎麼', '這麼', '快', '啊'] ['可是', '是你', '已經', '做', '得', '很', '可愛', '了']
# ['來', '你', '幫', '他', '登記', '一下', '阿輝', '不好', '不好意思', '好意', '好意思', '意思', '你', '這是', '別', '的', '郵局', '局開', '開戶', '的', '我們', '這裡', '不能', '存', '喔', '一樣', '都是', '是台', '台灣', '郵局', '的', '為什麼', '不行'] ['因為', '我們', '這', '行動', '郵局', '只', '限於', '在', '這裡', '開戶', '的', '才', '可以', '在', '這裡', '存']
# ['你們', '剛剛', '有聲', '聲音', '嗎', '當然', '有'] ['所以', '咱們', '蔓蔓', '沒', '聽到', '聲音', '也是', '應該', '的', '啦']
# ['來信', '真的', '是', '太', '踴躍', '了', '當然', '應該', '說', '是我', '我很', '很有', '魅力', '不然', '怎麼', '都', '指名', '要', '我', '幫忙', '很多', '多人', '被', '你', '的', '外表', '騙', '了', '其實', '論功', '功力', '來', '講', '我', '仍', '凌駕', '在', '你', '之上'] ['聽', '你', '亂說', '你', '真的', '是', '會', '吹牛']
# ['可是', '滅火', '滅火器', '火器', '基本', '上', '它', '不是', '因為', '美觀', '的', '時候', '才', '要', '用', '滅火', '滅火器', '火器', '是', '在', '你', '面對', '到', '災害', '的', '時候'] ['你', '方便', '用']
# ['你是', '說', '只要', '我', '在', '外型', '上', '做', '改變', '就', '可以', '化解', '了', '嗎'] ['看來', '最近', '大家', '對', '算命', '這', '件', '事情', '挺', '熱中', '的', '喔']
# ['不覺', '覺得', '我們', '相處', '時間', '太多', '了', '失去', '很多', '和', '其', '他', '同學', '相處', '的', '機會', '我', '做錯', '什', '麼'] ['沒有', '啊', '你', '沒有', '做錯', '什', '麼']
# ['我', '覺得', '你們', '好棒', '喔', '就是', '小小', '年紀', '可是', '對', '哈', '瑪星', '這', '個', '地區', '這麼', '瞭解', '你們', '是', '透過', '什', '麼', '方式', '來', '認識', '這', '個', '地方', '的'] ['學校', '都會', '有', '社區', '巡禮', '都會', '來到', '到處', '參觀']
# ['他', '當初', '的', '出發', '出發點', '發點', '也是', '為了', '我們', '為了', '這', '個', '家', '不是', '嗎', '就算', '他是', '為了', '我們', '這', '個', '家', '他也', '也不', '不能', '做', '違法', '的', '事', '啊'] ['奕瑄', '你', '說', '的', '沒有', '錯', '可是', '是你', '爸爸', '為', '他', '做', '的', '錯事', '也', '付出', '了', '代價', '不是', '嗎']
# ['你', '要', '幫', '我', '帶', '一', '包', '東西', '去', '給', '吳佩珊', '佩珊', '同學', '好', '沒', '問題', '那', '吳佩珊', '佩珊', '是誰'] ['她', '是台', '台大', '的', '學生', '她', '專門', '在', '研究', '神秘', '神秘果', '這樣']
# ['海浪', '大', '的', '時候', '海浪', '就', '會', '翻動', '比較', '較大', '的', '礫石', '把', '海底', '的', '礫石', '給', '沖上', '上岸'] ['所以', '我們', '把', '它', '阻擋', '擋下', '下來']
# ['它', '的', '手', '還會', '動', '耶', '有沒有', '沒有', '很', '可愛', '對', '啊', '可愛', '愛是', '很', '可愛', '啦', '但是', '對於', '我們', '男孩', '男孩子', '孩子', '來', '講'] ['也', '可以', '動動', '動動手', '動手', '喔']
# ['你', '那', '個', '水分', '要不', '要不要', '不要', '多', '一點', '你', '那', '個', '根本', '就', '沒有', '有水', '水分', '我', '放', '了', '啦', '那麼', '那麼少', '的', '水分', '等一下', '一下', '要', '加', '米酒', '酒不', '不是', '嗎'] ['你', '要', '加', '米酒', '你', '也是', '可以', '放水', '多', '一點']
# ['我', '跟', '大家', '補充', '一下', '寇', '家', '瑞', '先生', '是', '寇世勳', '世勳', '先生', '的', '兒子', '對', '可是', '很不', '像', '你', '有沒有', '沒有', '覺得'] ['那', '家', '瑞', '有一', '個', '孩子', '臉', '就是', '是非', '非常', '孩子', '孩子氣']
# ['你', '到底', '有沒有', '沒有', '去', '看醫生', '醫生', '啊', '感冒', '啦', '過', '兩', '天', '就好', '好了'] ['你', '還', '逞強', '看', '你', '咳', '成', '這樣', '這樣子', '樣子', '感冒', '可是', '是不', '不能', '拖', '的']
# ['陳', '韋', '辰', '你', '沒事', '吧', '沒關係', '關係', '不', '舒服', '就', '不要', '跑', '我', '幫', '你', '跟', '老師', '講'] ['你是', '什', '麼', '座', '的', '啊']
# ['開始', '搬', '東西', '師母', '開車', '師母', '怎樣'] ['最後', '有一', '天', '我們', '的', '製作', '製作人', '作人', '人黃', '黃玉', '玉明', '跟', '我', '說', '你知', '知道', '嗎', '師母', '是', '政大', '畢業', '的']
# ['我', '覺得', '很好', '所以', '自己', '給', '自己', '打', '幾', '分'] ['大家', '在', '罵', '的', '事情', '都', '差不', '差不多']
# ['我還', '以為', '是', '什', '麼', '新奇', '的', '玩具', '原來', '是我', '小時', '小時候', '時候', '就', '玩', '過', '的', '扯鈴'] ['我', '跟', '你', '說', '你不', '不要', '小看', '這', '個', '扯鈴', '這', '可是', '曾經', '讓', '外國', '外國人', '國人', '都很', '著迷', '的', '國寶', '玩具']
# ['不要', '一直', '逼', '我', '背', '台詞', '我', '的', '腦筋', '不好', '濂', '僑', '全天', '天下', '天下人', '下人', '人都', '知道', '濂', '僑', '你是', 'NG', '大王'] ['人家', '家當', '當然', '要緊', '盯', '著你', '練習', '是', '啊']
# ['她', '媽媽', '曾經', '是個', '犯人', '喔', '看不出來', '出來', '真的', '被', '她', '騙', '了', '她', '到底', '犯', '了', '什', '麼', '罪', '為什麼', '什麼會', '去', '坐牢', '呢'] ['我沒', '看到', '前面', '的', '報導', '只', '知道', '她曾', '曾經', '坐牢', '就', '對了']
# ['少', '瑄', '為了', '主奏', '陷害', '李', '芯', '怎麼', '這樣', '她們', '不是', '很好', '的', '朋友', '嗎', '太', '可怕', '怕了', '沒想到', '想到', '少', '瑄', '竟是', '這', '種', '人'] ['看來', '要', '多', '提防', '她', '了']
# ['你', '幹嘛', '推', '我', '啦', '弄破', '了', '是', '小中', '絆倒', '我', '的'] ['來', '我們', '來', '好好', '練', '一下']
# ['驚心', '驚心動魄', '心動', '動魄', '的', '滴血', '認親', '親情', '情節', '宮', '中', '貴妃', '被', '皇后', '誣陷', '與', '太醫', '有染', '指出', '所', '生', '的', '皇子'] ['並非', '是', '皇上', '的', '龍', '種']
# ['其實', '你', '跟', '她', '也', '很', '熟', '啊', '她', '就是', '知名', '的', '廣播', '主持', '主持人', '劉麗紅', '麗紅'] ['但是', '她', '是', '如何', '從', '一', '個', '自卑', '自憐', '痛苦', '矛盾', '的', '女孩']
# ['她', '要求', '我', '讓', '她', '到班', '班上', '向', '各', '位', '同學', '道歉', '老師', '陳媽媽', '媽媽', '又', '沒有', '做錯', '錯事', '為什麼', '要', '向', '我們', '道歉'] ['你', '早', '把', '事情', '說清', '說清楚', '清楚', '不', '就', '沒有', '這', '種', '情況', '了']
# ['面對', '這', '五花八門', '的', '小技', '技倆'] ['你', '能', '瞧出', '箇中', '奧妙', '嗎']
# ['我是', '說', '加上', '這', '個月', '的', '零用', '零用錢', '剛好', '存夠', '四', '千', '多', '塊', '啦', '是', '這樣', '那你', '存', '了', '多久', '你', '該不', '不會', '是', '偷', '你媽', '的', '錢', '來', '買', '的', '吧', '你', '說', '那', '什', '麼', '鬼話'] ['不如', '我', '的', '原因', '了']
# ['我', '覺得', '不公', '不公平', '公平', '我們', '都', '贏不了', '不了', '男生', '但', '老師', '卻', '說', '訣竅', '在', '以柔克剛'] ['沒關係', '關係', '大家', '公平', '競爭', '嘛']
# ['認識', '的', '同學', '我', '都', '打', '過', '啦', '同學', '都', '說', '他', '下', '了', '課', '之後', '就', '回家', '了', '奇怪', '我', '去', '公園', '球場', '看看', '看好', '好了'] ['那', '我', '去', '網咖', '看看', '看好', '好了']
# ['阿爸', '阿蘭', '身體', '本來', '就', '不太', '好', '她', '又', '很', '怕生', '啊', '再', '怎樣', '她', '也要', '來', '廟裡', '拜', '一下', '人家', '說', '有', '燒香', '有', '保佑', '咱', '討海', '討海人', '海人', '靠', '海', '吃飯'] ['好', '啦', '阿爸', '人', '少', '的', '時候', '我', '再', '帶', '阿蘭', '來', '燒香', '啦']
# ['不好', '不好意思', '好意', '好意思', '意思', '喔', '這樣', '這樣子', '樣子', '麻煩', '你們', '真的', '不好', '不好意思', '好意', '好意思', '意思'] ['現在', '時間', '很', '晚', '了', '我', '先', '送', '你', '回家']
# ['為什麼', '不給', '牠', '做成', '圓', '的', '因為', '做成', '圓', '的', '話'] ['我們', '再', '把', '它', '晾乾']
# ['不過', '這', '個', '本', '氏', '液', '是', '幹嘛', '用', '的', '你不', '不知', '知道', '喔', '來', '小中', '解釋', '解釋給', '給他', '聽'] ['沒', '問題', '看', '我', '的', '秘密', '檔案', '本', '氏', '液', '它', '是藍', '藍色', '的', '液體', '它', '是', '醣', '的', '指示', '指示劑']
# ['你是', '說', '我', '這一', '一生', '戀愛', '婚姻', '都不', '不可', '不可能', '可能', '會', '幸福', '啊'] ['拜託', '你不', '不要', '那麼', '全心', '的', '投入', '好不', '好不好', '不好']
# ['第', '一', '類', '在', '這裡', '這', '三', '個', '大概', '是', '對'] ['不可', '不可以', '可以', '說', '大概', '要', '確定', '是', '對', '一定', '是', '對']
# ['我', '本來', '想要', '參加', '加徵', '徵文', '比賽', '的', '結果', '這', '個', '題目', '是我', '的', '家庭', '要', '怎麼', '寫', '啊', '拜託', '好不', '好不好', '不好', '像', '這', '種', '老掉', '老掉牙', '掉牙', '的', '題目', '從小', '從小到大', '大我', '我們', '不知', '知道', '寫', '多', '少', '遍', '對', '啊', '這樣', '你', '還', '寫不出', '出來', '喔'] ['就是', '寫', '太多', '遍', '寫到', '最後', '我', '現在', '都沒', '感覺', '了']
# ['老師', '我怕', '我', '做', '不好'] ['你', '放心', '有', '這麼', '這麼多', '幫手', '在', '老師', '對', '你', '的', '才藝', '有', '信心', '好不', '好不好', '不好']
# ['是', '梁', '老師', '私底下', '底下', '把', '你', '那', '幅', '綠島', '風情', '風情畫', '寄', '去', '比賽', '的', '為什麼'] ['你', '的', '優異', '表現', '是我', '我們', '綠島', '島國', '國中', '的', '光榮']
# ['第一關', '一關', '實習', '要', '跟', '的', '是', '外科', '特地', '請', '了', '外科', '主任', '一起', '起來', '吃飯'] ['真的', '嗎', '心臟', '外科', '主任', '他是', '是我', '的', '偶像', '耶']
# ['原來', '是', '這樣', '啊', '難怪', '她', '一直', '跟', '我', '收', '利息', '我還', '一直', '賒帳', '跟', '她', '買', '東西', '真的', '很不', '不好', '不好意思', '好意', '好意思', '意思', '沒有', '有關', '關係', '老師', '知道', '你是', '無心', '的'] ['所以', '這', '些', '錢', '是', '她們', '自己', '光明', '光明正大', '明正', '正大', '賺回', '賺回來', '回來', '的']
# ['你', '有', '想', '過去', '流浪', '嗎', '好像', '有', '過', '吧', '阿明'] ['不是', '丟', '了', '什', '麼', '東西']
# ['你們', '到底', '要', '借', '竹竿', '做', '什', '麼', '我們', '要', '比賽', '撐竿', '撐竿跳', '你是', '說真的', '真的', '還是', '是假', '的'] ['當然', '是', '真的', '啊']
# ['沒有', '有人', '知道', '這', '件', '事', '可是', '是我', '自己', '就', '這樣', '臉紅', '到', '不行', '覺得', '丟臉', '可是', '是你', '父親', '母親', '知道', '這', '件', '事', '嗎', '不知', '知道', '他們', '也不', '不知', '知道', '都不', '不知', '知道'] ['所以', '你', '的', '人生', '經歷', '是非', '非常', '豐富', '的']
# ['我就', '簡短', '的', '回答'] ['孩子', '還', '在', '念書', '的', '時候']
# ['涂', '先生', '那一', '次', '養', '那麼', '那麼多', '的', '蠶', '平常', '要', '怎麼', '照顧', '牠們', '啊', '我們', '只有', '餵', '桑葉', '給', '牠', '吃', '就', '可以', '了', '現在', '正在', '牠', '要', '餵食', '的', '時間'] ['那', '我們', '趕快', '餵', '牠', '吃']
# ['你', '怎麼', '能', '把', '自己', '弄成', '這樣'] ['我有', '怎麼', '怎麼樣', '嗎']
# ['那', '可不可以', '不可', '不可以', '可以', '用', '一', '些', '科學', '的', '實驗', '或者', '是', '原理', '去', '驗證', '它', '呢'] ['太極', '太極拳', '的', '一', '個', '原理', '當然', '是', '可以', '用', '科學', '的', '方法', '來', '驗證', '它']
# ['就是', '這', '位', '單親', '爸爸', '他', '因為', '絕望', '打算', '抱', '著', '女兒', '要', '從', '天橋', '橋上', '跳下', '跳下去', '下去'] ['在', '艱困', '的', '環境', '下', '如何', '互相', '扶持']
# ['山水', '還', '有一', '個', '很', '著名', '的', '風味', '食材', '你知', '知道', '是', '什', '麼', '嗎', '提示', '一下', '嘛', '風'] ['好山', '好水', '好', '風光']
# ['我', '也', '知道', '則', '緯', '是', '因為', '喜歡', '我', '才', '這樣', '做', '但是', '是我', '真的', '只是', '把', '他', '當成', '好', '同學', '而已'] ['人家', '孩子', '在', '開玩笑', '玩笑', '你', '當作', '真的', '啊']
# ['一手', '一手交錢', '一手', '一手交貨', '交貨', '五', '十', '元', '先', '拿來', '我', '忘記', '帶', '了', '嘛', '先', '欠', '一下', '又', '不會', '怎樣', '我', '明天', '再', '還', '你'] ['不行', '你', '每', '次', '都', '說明', '明天']
# ['鄭永', '永銘', '老師', '執教', '物理', '二十七年', '十七年', '七年', '最', '擅長', '將', '枯燥', '難懂', '的', '科學'] ['化為', '神奇', '有趣', '的', '魔術']
# ['我', '用', '腳', '踢', '或是', '是我', '用', '拳頭', '打', '可不可以', '不可', '不可以', '可以'] ['不行', '那', '完全', '犯規', '你不', '不能', '去', '攻擊', '攻擊人', '人家']
# ['我', '看', '別', '說', '什', '麼', '奧運', '運金', '金牌', '黑', '帶', '可能', '都有', '問題', '我', '大概', '只要', '要能', '往', '上升', '一級', '我就', '就要', '偷笑', '了'] ['我', '可以', '這樣', '擊破', '木板', '是', '因為', '有', '教練', '在', '旁邊', '監督', '指導', '我', '你們', '在', '家', '可', '千', '萬', '不要', '偷學', '喔']
# ['詠', '真', '為什麼', '不', '直接', '告訴', '我', '她', '不', '喜歡', '我', '還', '讓我', '這樣', '一頭', '熱', '的', '為', '她', '做', '那麼', '那麼多', '多事'] ['她', '有', '拒絕', '過', '你', '啊', '只是', '是你', '沒有', '聽進', '聽進去', '進去']
# ['思卉', '你', '晚上', '有沒有', '沒有', '要去', '哪裡', '晚上', '啊', '我', '應該', '該會', '去', '阿輝', '那兒', '吧', '你', '要', '跟', '我一', '一起', '去', '嗎'] ['好', '啊', '最近', '真是', '太忙', '了']
# ['蟑螂', '丟到', '可樂', '裡', '會', '被', '腐蝕', '光光', '啊', '天天', '喝', '小心', '你', '的', '胃'] ['正好', '拿', '可樂', '來', '把', '它', '刮', '一', '刮']
# ['濂', '僑', '那你', '有', '什', '麼', '夢想', '夢想', '實現', '了沒', '沒有', '呢'] ['我', '的', '夢想', '是', '希望', '以後', '可以', '成為', '一', '位', '手語', '手語界', '的', '名師', '你', '呢']
# ['你知', '知不知道', '不知', '知道', '這', '附近', '有一', '間', '招待', '招待所', '招待', '招待所', '就是', '這', '片', '樹林', '後面', '有一', '棟', '日本', '房子'] ['這裡', '是', '桃園', '桃園縣', '龍潭', '龍潭鄉', '的', '觀光', '光大', '大池']
# ['為什麼', '我們', '都', '看', '不', '到', '扁柏', '的', '神木'] ['松樹', '柏樹', '這', '都很', '長壽', '啊']
# ['是妳', '自己', '放棄', '的', '好不', '好不好', '不好'] ['妳', '以為', '我', '願意', '啊']
# ['你們', '怎麼', '這樣', '這樣子', '樣子', '拿', '一', '個', '望遠', '望遠鏡', '在', '偷窺', '我', '哦', '沒', '禮貌', '這', '望遠', '望遠鏡', '哪', '是', '用來', '偷窺', '的', '這', '用來', '觀察', '星星', '的', '好不', '好不好', '不好', '觀察', '什', '麼', '星星'] ['也是', '可以', '看', '別', '的', '星星', '的', '啦']
# ['你', '說', '我', '該', '怎麼', '怎麼辦', '嘛', '你', '怎麼', '可以', '做', '這樣', '的', '事情'] ['要不', '要不然', '不然', '你', '要', '我', '怎麼', '怎麼辦']
# ['姊姊', '知道', '蔡依林', '嗎', '我不', '不知', '知道', '不知', '知道'] ['是', '喔', '那', '姊姊', '知道', '道周', '周杰倫', '杰倫', '嗎']
# ['那你', '想', '蓋', '什', '麼', '樣', '的', '學校'] ['小朋友', '朋友', '要', '自己', '製造', '自己', '的', '家', '啊']
# ['暑假', '快要', '結束', '了', '你', '幫', '你', '的', '小孩', '做', '了', '什', '麼', '樣', '的', '暑期', '規劃', '啊', '在', '他們', '還沒', '沒有', '放暑假', '暑假', '之前', '早就', '計劃', '計劃好', '好了'] ['那你', '你們', '知不知道', '不知', '知道', '有一', '個', '暑期', '的', '兒童', '兒童戲', '戲劇', '戲劇課', '課程', '的', '活動', '啊']
# ['這', '大概', '就是', '是我', '唯一', '一會', '在', '外面', '用餐', '的', '機會', '主要', '目的', '就是', '是要', '介紹', '一', '個'] ['幼華', '在', '其', '中', '換到', '了', '生活', '生活樂', '樂趣']
# ['快', '睡著', '了', '快', '睡著', '了', '喔'] ['對', '啊', '昨天', '晚上', '沒', '睡']
# ['我', '記得', '有一', '次', '孩子', '打電話', '電話', '跟', '爸爸', '說', '我', '考到', '大學', '了'] ['可是', '爸爸', '沒有', '回應', '他']
# ['濂', '僑', '你', '念', '中學', '的', '時候', '最', '拿手', '的', '是', '哪', '個', '科目', '最不', '拿手', '的', '又', '是', '哪', '個', '科目'] ['我', '想想', '啊', '我', '覺得', '我', '對數', '數學', '很有', '有興', '興趣']
# ['妳', '希望', '自己', '考上', '哪', '所', '大學', '對', '自己', '未來', '的', '期望', '是', '什', '麼', '呢'] ['我', '希望', '考上', '上師', '師範', '大學', '然後', '用', '我', '四年', '的', '時間', '在', '裡面', '好好', '的', '學習', '很多', '東西']
# ['醫生', '病人', '怎麼', '怎麼樣', '啦'] ['病人', '現在', '已經', '沒', '什', '麼', '大礙', '只', '需要', '住院', '觀察', '幾', '天']
# ['你們', '家屬', '同意', '同意書', '手術', '同意', '同意書', '填好', '好了', '嗎', '可是', '他', '奶奶', '我們', '還沒', '找到', '呀'] ['家屬', '先', '在', '外面', '等一下', '一下']
# ['我是', '是不', '不是', '是要', '這樣', '一直', '翻', '一直', '翻', '這樣', '這樣子', '樣子'] ['是不', '不用', '這樣', '啦', '差不', '差不多', '兩', '小時', '翻', '一', '次', '啦']
# ['其實', '我', '真正', '想', '讀', '的', '是', '餐飲', '餐飲科', '每', '次', '看到', '烹飪', '的', '書', '就', '會很', '很有', '精神'] ['好', '啊', '如果', '你', '沒辦法', '辦法', '趕上', '我', '那', '乾脆', '我', '考差', '差一點', '一點', '跟', '你', '一起', '去', '讀', '職校', '好了']
# ['現在', '還', '有車', '車子', '去', '瀘', '沽', '湖', '嗎'] ['沒有', '有車', '了']
# ['你', '要', '學', '起來', '喔', '好', '我要', '拿', '這', '個', '打天下', '天下'] ['你', '要', '學', '得', '像', '喔', '學', '不', '像', '你', '就', '完蛋', '了', '我', '跟', '你', '講']
# ['奶奶', '你', '在', '這', '個', '眷村', '有沒有', '沒有', '什', '麼', '最難', '難忘', '的', '生活'] ['我', '最難', '難忘', '的', '就是', '鄰居', '大家', '出來', '聊天']
# ['我', '想要', '請假', '你', '要', '請', '多久', '啊'] ['妳', '要不', '要不要', '不要', '上來', '坐', '一下']
# ['我', '問', '你', '當初', '你', '怎麼', '會', '喜歡', '做', '中國', '中國結', '呢'] ['牆', '上', '這麼', '這麼多', '的', '中國', '中國結', '都是', '是你', '編', '的']
# ['那', '新', '的', '一年', '你', '有', '什', '麼', '新', '希望', '啊'] ['我', '希望', '世界', '和平', '不要', '再', '有', '戰亂']
# ['我', '覺得', '這', '個', '媳婦', '很好', '啊', '超好', '的', '啦', '超好', '的', '哪裡', '好'] ['等一下', '一下', '我', '放給', '給你', '看']
# ['我們', '只是', '利用', '這', '個', '圖片', '來', '引發', '內在', '的', '情緒', '去', '讓', '創作', '作者', '去', '投射', '他', '的', '感覺'] ['因為', '這', '些', '感覺', '有時', '有時候', '時候', '可能', '很難', '難說', '得', '清楚']
# ['這', '枝', '筆桿', '啊', '全', '部', '都是', 'K', '金', '做', '的', '漂亮', '吧', '真的', '好', '漂亮', '喔', '你', '爸爸', '怎麼', '捨得', '給你', '啊'] ['這', '次', '段考', '我', '進步', '很多', '我', '爸爸', '給', '我', '的', '獎品']
# ['你', '看', '我', '的', '我', '的', '這樣', '隨便', '這樣', '一', '放', '它', '就', '飛上', '飛上去', '上去', '啦', '怎麼', '會', '這樣'] ['我', '也不', '不知', '知道', '它', '就是', '飛', '不', '起來']
# ['依', '君', '我有', '有禮', '禮物', '要', '送給', '給你'] ['這', '份', '禮物', '是', '跟', '老師', '賠罪', '的']
# ['流傳', '的', '滴血', '認親', '卻有', '另一', '番', '註解', '不僅', '認為', '滴血', '認親', '不可', '可靠', '甚至', '說出', '只要', '血型', '相同'] ['眼見', '見黃', '黃同', '同學', '讓', '石斑', '石斑魚', '安定', '後']
# ['開玩笑', '玩笑', '我', '自己', '喝', '飽', '回來', '就好', '我', '幹嘛', '還', '帶回', '帶回來', '回來', '給你', '你們', '喝'] ['你', '怎麼', '這樣', '這樣子', '樣子', '啊', '小氣']
# ['現在', '在先', '請', '老師', '給', '我們', '博愛', '愛國', '國小', '分數', '請', '舉', '牌'] ['扣掉', '的', '分數', '加', '起來', '比', '我們', '得', '的', '分數', '還要', '多']
# ['賢賢', '聽', '你', '這麼', '講', '就', '知道', '你', '一定', '沒有', '坐', '過', '阿里', '阿里山', '里山', '山火', '火車', '是', '嗎', '我是', '真的', '沒有', '坐', '過', '難道', '你們', '都有', '坐', '過', '嗎'] ['賢賢', '你們', '在', '說', '什', '麼', '鹽田']
# ['妳', '今天', '幹嘛', '吃', '那麼', '那麼多', '多肉', '啊'] ['我', '明天', '就', '不能', '吃', '啦']
# ['所有', '的', '科目', '我', '都', '幫', '你', '整理', '在', '筆記', '筆記本', '裡', '了', '而且', '我', '都', '做好', '標記', '分類', '你', '花', '多久', '的', '時間', '整理', '的'] ['這', '個', '你不', '不要', '管', '只要', '讓', '你', '有好', '成績', '花', '多', '少時', '時間', '我', '都', '願意']
# ['每逢', '年底', '聖誕', '佳節', '的', '前夕', '他會', '裝扮', '裝扮成', '扮成', '耶誕', '老公', '老公公', '公公', '幫忙', '募款'] ['作為', '照顧', '身心', '身心障', '心障', '障礙', '朋友', '的', '經費']
# ['怎麼', '怎麼樣', '可以', '動', '嗎', '我', '小心', '一點', '應該', '可以', '啦', '怎麼', '打', '個', '球', '打成', '這樣', '這樣子', '樣子', '嘛'] ['只是', '扭到', '擦傷', '而已', '您', '不用', '大驚', '大驚小怪', '啦']
# ['你', '看', '他們', '的', '婚姻', '你', '覺得', '好', '嗎', '不一', '不一定', '一定', '定都', '都不', '不好'] ['一定', '有好', '的', '啊']
# ['你', '現在', '一', '天大', '大概', '還要', '喝多', '少'] ['頂多', '不會', '超過', '兩', '瓶']
# ['阿', '火', '叔', '你', '有沒有', '沒有', '看到', '我家', '家阿', '阿蘭', '有', '呀', '說', '要', '帶', '小孩', '去', '海邊', '走走'] ['你是', '是不', '不是', '常', '帶', '女孩', '女孩子', '孩子', '來', '這裡', '來', '海邊', '玩']
# ['這裡', '的', '養', '蝦', '場', '是', '用', '海水', '水養', '養殖', '蝦', '而且', '今天', '我們', '來', '的', '日子', '剛好', '是', '他們', '收', '蝦', '的', '日子', '收', '蝦', '是', '什', '麼', '是', '蝦子', '收成', '嗎'] ['對', '就是', '蝦子', '收成']
# ['你', '今天', '的', '狀況', '不是', '很好', '彈琴', '的', '力道', '道明', '明顯', '都不', '不足', '該', '重', '的', '音階', '幾乎', '都', '只是', '輕輕', '帶過'] ['而', '該', '輕', '的', '地方', '幾乎', '都', '聽', '不', '到']
# ['而且', '我', '相信', '你', '在', '那', '兩', '分鐘', '的', '獨奏', '奏表', '表演', '一定', '會', '得到', '最多', '的', '掌聲', '謝謝', '你', '你', '真的', '是', '最', '最', '最', '夠', '朋友', '了'] ['我是', '真的', '沒辦法', '辦法']
# ['有', '這樣', '的', '想法', '那是', '是一', '件', '很棒', '的', '事', '沒有', '也', '有人', '不願', '願意', '演', '啦'] ['可是', '很多', '演員', '再', '怎麼', '辛苦', '都', '願意', '繼續', '跟', '老師', '師合', '合作']
# ['我很', '很多', '多事', '事情', '都不', '不會', '跟', '他', '討論', '然後', '發現', '做', '了', '之後', '他不', '喜歡'] ['然後', '就', '自己', '進房', '房間', '念書']
# ['所以', '經過', '離心', '以後', '呢', '上面', '就', '分為', '血清', '下面', '就', '分為', '血球'] ['重', '的', '血球', '就', '沉下', '下來', '了', '對', '不對']
# ['我', '看', '你', '回到', '家', '到', '現在', '一', '句', '話', '也不', '講', '你是', '是不', '不是', '在學', '在學校', '學校', '發生', '什', '麼', '事'] ['你', '的', '腦袋', '就是', '跟', '別人', '想', '的', '不一', '一樣']
# ['冒泡', '的', '感覺', '是', '什', '麼', '啊'] ['究竟', '沖繩', '的', '魅力', '在', '哪裡', '呢']
# ['我們', '馬上', '上去', '看醫生', '醫生', '好', '嗎', '不行', '啦', '如果', '這時', '時候', '去', '看醫生', '醫生'] ['醫生', '一定', '叫', '我要', '多', '休息', '不要', '彈琴']
# ['你', '跟', '阿', '陽', '在一起', '一起', '那麼', '久', '了', '那', '現實', '生活', '當中', '你是', '他', '的', '什', '麼', '還不是', '不是', '只是', '普通', '朋友', '嗎', '誰', '說', '我們', '只是', '普通', '朋友', '我們', '的', '關係', '你又', '不是', '是不', '不知'] ['誰', '承認', '你們', '的', '關係', '啊', '難道', '你', '可以', '當', '著大', '大家', '的', '面', '說', '你是', '他', '的', '未亡', '未亡人', '嗎']
# ['你是', '是不', '不是', '喝醉', '啦', '我', '跟', '你', '說', '我就', '在', '附近', '我', '去', '接', '你', '喔', '不用', '了', '啦'] ['我', '給你', '時間', '好好', '的', '考慮', '考慮考慮', '考慮']
# ['媽', '如果', '我', '去', '讀', '餐飲', '餐飲科', '而', '不去', '讀', '普通', '高中', '呢'] ['那', '也', '很好', '啊', '只要', '你', '自己', '想清楚', '清楚', '你', '做', '任', '何', '決定', '媽', '都', '支持', '你', '加油']
# ['但是', '透過', '廣播', '呢', '我', '自己', '給', '我', '自己', '的', '心靈', '做', '了一', '個', '很好', '的', '治療', '跟', '聽眾', '朋友', '朋友們', '友們', '的', '互動'] ['也讓', '讓我', '感到', '非常', '的', '溫暖']
# ['可是', '是你', '你不', '不是', '是也', '也是', '合唱', '合唱團', '的', '候補', '伴奏', '嗎', '你不', '不用', '準備', '嗎', '反正', '我只', '只是', '是個', '候補', '比較', '沒關係', '關係', '啦'] ['你', '今天', '的', '狀況', '不是', '很好']
# ['就是', '這', '位', '單親', '爸爸', '他', '因為', '絕望', '打算', '抱', '著', '女兒'] ['就是', '單親', '親家', '家庭', '庭長', '長大', '的', '小孩']
# ['我', '用來', '裝', '錢', '的', '包包', '不見了', '錢不', '見', '啦', '怎麼', '會', '不見了', '呢'] ['不要', '老是', '躲', '著不', '見', '人', '嘛']
# ['那時', '時候', '其實', '你們', '都', '還', '很', '小', '耶', '對', '啊', '除了', '那', '個', '總監', '很老', '之外'] ['當然', '他們', '都', '覺得', '很', '討厭']
# ['不能', '因為', '你', '幫', '我', '這一', '一點', '小小', '的', '忙', '就要', '我', '買', '那', '雙鞋', '送', '你', '媽', '你', '想到', '哪', '去', '了', '我', '這', '次', '是', '義務', '幫忙', '沒有', '任', '何', '條件', '的', '你', '放心', '好了', '那你', '要', '確實', '把', '它', '清理', '乾淨', '喔'] ['太', '可惡', '了']
# ['土星', '的', '體積', '非常', '的', '大', '是', '地球', '的', '七', '百', '四', '十', '五倍', '耶', '真的', '啊'] ['你們', '知道', '嗎', '土星', '的', '體積', '很大', '哦']
# ['所以', '你們', '家用', '得', '最多', '的', '應該', '就是', '紙', '跟', '筆', '了', '吧', '是不', '不是', '是', '然後', '很多', '多人', '說', '你們', '家', '是', '用', '稿紙', '紙糊', '起來', '的', '是', '因為', '真的', '是', '爸爸', '爸媽', '媽媽', '真的', '就是', '靠', '筆耕'] ['還好', '爸爸', '那時', '時候', '他是', '是軍', '軍職', '那', '軍職', '至少', '少有', '固定', '的', '軍餉']
# ['怎麼', '培養', '我們', '然後', '怎麼', '教', '我們', '寫文', '文章', '從來', '沒有', '沒有', '嗎'] ['看到', '他', '的', '那', '個', '寫作', '的', '身影']
# ['那', '米開朗基羅', '開朗', '基', '羅', '牠', '的', '個性', '是', '怎麼', '怎麼樣', '的', '蠻', '凶悍', '的', '吧', '蠻', '凶悍', '喔', '所以', '我們', '不可', '不可以', '可以', '以太', '接近', '牠', '是不', '不是'] ['你', '平常', '除了', '刷', '馬', '之外', '還要', '幫', '馬', '做', '些', '什', '麼', '事', '嗎']
# ['張', '瑞', '桓', '我', '到處', '找', '你', '英文', '講義', '的', '錢', '你', '還沒', '交', '喔', '來不及', '不及', '囉', '我', '現在', '口袋', '空空', '是也'] ['明明', '交', '錢', '那麼', '簡單', '的', '事', '為什麼', '你', '可以', '拖', '那麼', '久']
# ['簡單', '的', '說', '這是', '是一', '種', '先天', '先天性', '天性', '的', '心臟', '心臟病', '醫生', '那', '我們', '該', '怎麼', '怎麼辦'] ['我們', '馬上', '上去', '看醫生', '醫生']
# ['李', '芯', '這樣', '好', '嗎', '我', '也不', '不知', '知道', '但是', '是不', '不管', '怎麼', '怎麼樣'] ['你', '一定', '要', '幫', '我', '保守', '這', '個', '秘密']
# ['面目', '面目可憎', '可憎', '可能', '不只', '只是', '因為', '沒有', '讀書', '吧', '也', '有', '可能', '是', '因為', '睡眠', '不足'] ['也', '有', '可能', '是', '年紀', '到', '了', '啊']
# ['小姐', '妳', '不知', '知道', '這裡', '不能', '貼', '嗎', '貼成', '這麼', '亂', '要', '開', '單', '喔', '大哥', '不好', '不好意思', '好意', '好意思', '意思', '啦', '我是', '新來', '的', '不知', '知道', '規矩'] ['我', '抓到', '妳', '卻', '沒有', '開', '單', '的', '話', '我會', '被', '長官', '罵']
# ['下', '過', '雨', '後山', '中', '的', '溪水', '湍急', '水流', '衝力', '較大', '難不成', '不成', '這', '第一關', '一關', '就', '會讓', '狗狗', '追', '不下', '下去', '了', '嗎'] ['繼續', '馬不停蹄', '不停', '蹄', '的', '逃亡', '完全', '不敢', '浪費', '費時', '時間']
# ['羽', '君', '對不起', '都是', '媽', '的', '錯', '你', '聽', '媽', '解釋', '嘛'] ['你', '走開', '我不', '想', '跟', '你', '說話']
# ['所以', '這', '個', '編劇', '寫', '故事', '的', '人', '是你', '嗎', '當然', '是我', '自己', '啦'] ['我', '覺得', '陽春', '陽春麵', '很好', '好吃']
# ['可見', '可見得', '見得', '由', '這', '個', '實驗', '我們', '發現', '看起來', '起來', '新鮮', '的', '蝦', '不見得', '見得', '真的', '比較', '較新', '新鮮'] ['所以', '其實', '我們', '購買', '海鮮', '的', '時候', '不能', '光', '看', '牠', '的', '外表']
# ['怎麼', '咳', '個', '不停', '的', '你', '到底', '有沒有', '沒有', '去', '看醫生', '醫生', '啊', '感冒', '啦', '過', '兩', '天', '就好', '好了'] ['你', '還', '逞強', '看', '你', '咳', '成', '這樣', '這樣子', '樣子', '感冒', '可是', '是不', '不能', '拖', '的']
# ['那', '失智', '的', '余', '爺爺', '呢', '他也', '能夠', '自己', '打理', '三', '餐', '嗎', '因為', '沒', '時間', '煮飯', '啊', '帶', '孩子', '怎麼', '有時', '時間', '煮飯'] ['他', '都會', '自己', '去', '買', '吃', '的']
# ['所以', '施打', '過', '一氧化碳', '氧化', '化碳', '的', '鮭魚', '會', '變得', '鮮紅', '而', '不會', '氧化', '氧化成', '化成', '化成為', '成為', '黑褐色', '褐色', '所以', '像', '有', '些', '人', '煤氣', '燒炭', '自殺', '之後', '他', '的', '皮膚', '都', '變得', '比較', '粉紅', '粉紅色', '紅色', '是一', '一樣', '的', '道理', '囉'] ['是', '一氧化碳', '氧化', '化碳', '吸進', '進去', '以後', '就', '跟', '我們', '的', '血液', '做', '結合', '所以', '會', '變成', '非常', '鮮紅']
# ['我', '跟', '你', '爸', '賺錢', '很', '辛苦', '你', '花起來', '起來', '倒', '蠻', '大方', '的', '你', '一點', '都不', '心疼', '啊'] ['我', '以後', '賺錢', '還', '你', '嘛']
# ['那', '幫', '老師', '畫有', '有沒有', '沒有', '有打', '打折', '老師', '人人', '平等', '不二', '不二價', '不過', '我', '保證', '把', '老師', '畫', '得', '美美', '的', '而且', '物超所值'] ['那', '當然', '了', '老師', '相信', '你', '的', '能力']
# ['賢賢', '喜歡', '我們', '這裡', '嗎', '很', '喜歡', '啊', '我', '覺得', '雖然', '校園', '整個', '校地', '並', '沒有', '很大'] ['可是', '每', '個', '人', '的', '感情', '好像', '都很', '很好']
# ['那', '如果', '我們', '想', '逛逛', '的', '話', '有', '什', '麼', '可以', '推薦', '的', '山形', '屋'] ['那', '有', '什', '麼', '特別', '的']
# ['舒', '琪', '你', '可以', '教', '我們', '做', '這', '種', '餅乾', '嗎'] ['對', '啊', '我', '超愛', '草莓', '口味', '的']
# ['加', '生', '你知', '知道', '瑉', '琁', '做', '這', '個', '研究', '的', '用意', '意在', '哪裡', '嗎'] ['怪', '難為', '難為情', '的', '對', '不對']
# ['你', '就', '先', '和', '珮甄', '借', '好了', '不要', '我', '最', '討厭', '欠', '人情', '了', '不然', '你', '想', '怎樣'] ['我', '保證', '明天', '我一', '一定', '交']
# ['有沒有', '沒有', '很開', '開心', '很開', '開心', '對', '啊', '現在', '在在', '收成', '啊'] ['當然', '是', '很開', '開心', '囉']
# ['芷', '穎', '我要', '向', '你', '收', '那', '個', '校外', '外教', '教學', '的', '費用', '啊', '我', '又', '忘了'] ['又', '忘了', '我', '看', '你是', '把', '錢', '拿去', '買', '漫畫', '漫畫書', '了', '吧']
# ['您', '所', '撥', '的', '電話', '號碼', '是', '空號'] ['是', '下一', '期', '大樂', '大樂透', '樂透', '的', '號碼']
# ['你', '的', '女兒', '是一', '位', '優秀', '的', '聽障', '孩子', '你', '對', '她', '有', '什', '麼', '期望', '呢'] ['我一', '一直', '幫', '她', '規劃', '說', '朝著', '能夠', '以', '聽障', '人', '的', '立場', '去', '考量', '以後', '後一', '些', '聽障', '的', '事物']
# ['我們', '去', '游泳'] ['我們', '身材', '又', '不一', '一樣']
# ['老師', '您', '會不會', '不會', '像', '其', '他人', '一樣', '看不起', '我', '媽媽', '為什麼', '要', '看不起', '她', '呢'] ['因為', '她', '犯', '過', '罪']
# ['王小', '王小弟', '小弟', '的', '那', '個', '聲音', '啊', '真的', '好像', '小朋友', '朋友', '的', '聲音', '你是', '怎麼', '詮釋', '的'] ['是一', '個小', '男孩', '的', '感覺', '嘛', '所以', '就', '像', '一', '個', '跟', '奶奶', '在', '撒嬌', '的', '小', '男孩', '的', '感覺']
# ['接下', '接下來', '下來', '我們', '要', '做', '裁剪', '的', '工作', '先', '把', '對角', '畫', '起來', '然後', '我們', '剪下', '剪下來', '下來', '就', '可以', '了', '老師', '在', '剪接', '修', '邊', '的', '時候', '有沒有', '沒有', '要', '特別', '注意', '什', '麼'] ['特別', '注意', '就是', '就是說', '我們', '要', '沿著', '直線', '要', '剪', '直']
# ['你', '說', '是', '莽撞', '也好', '或者', '說', '她', '是一', '個', '叛逆', '是一', '個', '這樣', '真性', '性情', '對', '很真', '真性', '性情', '的', '人', '不是', '而且', '這樣', '聽', '你', '講', '我就', '可以', '想像', '當年', '你媽', '媽媽', '就', '帶', '著', '狗', '在', '草原', '上', '奔騰', '的', '那', '種', '感覺'] ['可是', '像', '媽媽', '您', '母親', '這麼', '喜歡', '這', '些', '小', '動物', '們', '是不', '不是', '是也', '影響', '影響到', '你們', '整個', '家庭', '生活', '呢']
# ['那你', '今天', '要', '教', '我們', '什', '麼', '老師', '像', '你們', '之前', '前不', '不是', '是有', '問', '過', '我', '說', '嗎', '像', '我們', '一般', '吃', '這', '種', '綠綠', '的', '棗子', '是不', '不是', '是一', '一樣', '的', '人家', '說', '不能', '吃', '你不', '不要', '拿'] ['還是', '因為', '品種', '的', '改良']
# ['他們', '吃', '麵', '的', '時候', '會', '發出', '出聲', '聲音', '那你', '可不可以', '不可', '不可以', '可以', '示範', '一下', '他們', '吃', '麵', '怎麼', '怎麼樣', '吃法'] ['就', '這樣', '啊', '這樣', '好像', '很好', '好吃', '的', '感覺']
# ['她', '每', '次', '都', '這樣', '先', '給', '別人', '一點', '甜頭', '再', '叫', '別人', '替', '她', '做', '事情', '呢'] ['還好', '吧', '她', '也', '有', '不得', '不得已', '的', '苦衷', '幹嘛', '要', '把', '人家', '想', '這麼', '壞']
# ['打', '了一', '一氧化碳', '氧化', '化碳', '之後', '後會', '會讓', '讓魚', '看起來', '起來', '比較', '較新', '新鮮', '那會', '會不會', '不會', '跟', '吊白', '白塊', '一樣', '危害', '害人', '人體'] ['不會', '危害', '害人', '人體']
# ['那', '涂', '先生', '你知', '知不知道', '不知', '知道', '這', '附近', '哪', '邊', '有人', '在', '做', '這', '個', '蠶絲', '被', '啊'] ['這裡', '應該', '就是', '桑園', '囉']
# ['怎麼', '都不', '不給', '我', '吃', '小氣', '小氣鬼', '我', '這', '個', '可以', '啃', '很久'] ['可是', '是我', '想', '吃', '一口', '乖乖', '玉米', '棒']
# ['拿來', '我', '看', '不行', '你', '真的', '很', '粗魯', '沒錯', '像', '她', '恰北北', '北北', '的', '女生', '我是', '絕對', '不會', '投', '她', '一', '票', '的'] ['你們', '男生', '真的', '很', '無聊', '耶', '玩', '什', '麼', '投票', '幼稚']
# ...
# ['可不可以', '不可', '不可以', '可以', '麻煩', '你', '進去', '幫', '我', '問問', '問問看', '看看', '我', '男朋', '男朋友', '朋友', '在', '不', '在', '好不', '好不好', '不好'] ['你', '剛剛', '你', '男朋', '男朋友', '朋友', '我', '也不', '認識']
# ['林大', '大哥', '這是', '做', '什', '麼', '用', '的', '啊', '我們', '這', '個', '是', '在', '控制', '這', '三', '十', '八', '條', '路線', '是要', '讓', '火車', '車進', '進來', '出去', '還是', '轉彎'] ['可以', '示範', '看看', '嗎']
# ['二', '一一', '一一年', '一年', '三月', '十一日', '一日', '日本', '發生', '了', '芮氏', '規模', '九', '點', '零', '的', '地震'] ['並且', '引發', '驚人', '的', '海嘯']
# ['你是', '鄭', '叔叔', '嗎', '對', '啊', '你好', '我是', '小中', '叔叔', '我', '想要', '體驗', '驗水', '水上', '水上人家', '上人', '人家', '的', '生活'] ['可以', '帶', '我', '去', '體驗', '一下', '嗎']
# ['你們', '這', '些', '業務', '真', '現實', '現在', '不過', '是一', '個', '凶宅', '就要', '我', '求', '你們', '啊', '聽說', '那', '間', '房子', '出', '過', '很多', '多事', '事情', '熟門', '熟路', '都', '知道', '大家', '有所', '顧忌', '賀', '總', '可以', '讓我', '試試', '試試看', '試看', '嗎'] ['當', '我', '和', '阿伯', '下定', '下定決心', '決心', '環遊', '世界', '心', '裡', '總', '有', '微微', '的', '恐慌']
# ['那你', '在', '編', '什', '麼', '頭', '帶'] ['就是', '是要', '綁', '在', '頭上', '的', '那', '種', '嗎']
# ['平常', '有沒有', '沒有', '什', '麼', '秘訣', '保養', '喉嚨'] ['答案', '就要', '揭曉', '了']
# ['奕瑄', '你', '還好', '吧', '老師', '我', '真的', '沒有', 'A', '大家', '的', '錢', '你不', '不要', '聽', '芷', '穎', '亂', '講', '你', '要', '相信', '我'] ['雖然', '老師', '相信', '你', '沒有', '抽煙', '可是', '是你', '上', '頂樓', '就是', '是不', '不對', '阿']
# ['不過', '過老', '老師', '現在', '沒有', '男朋', '男朋友', '朋友', '所以', '我', '想', '請你', '幫', '我', '設計', '一', '條', '貝殼', '做', '的', '項鍊', '好不', '好不好', '不好', '沒', '問題', '我', '明天', '就', '可以', '拿給', '給你'] ['老師', '這是', '是我', '我們', '向', '妍', '如', '買', '的', '貝殼', '飾品', '是', '她', '自己', '設計', '的']
# ['所以', '今天', '天下', '下午', '我', '應該', '是', '沒有', '有辦', '辦法', '變成', '黑', '帶', '了'] ['是不', '不可', '不可能', '可能']
# ['如果', '你們', '這樣', '要', '出國', '表演', '的', '話', '打包', '包起', '起來', '大概', '有', '多', '少', '行李', '啊', '我們', '上', '次', '出國', '的', '話', '我們', '們大', '大概', '有七', '件', '大', '行李'] ['陳大', '大哥', '會', '事先', '準備', '很多', '的', '行李', '行李箱', '然後', '把', '水果', '放', '在', '其', '中', '一', '個', '行李', '行李箱', '裡面']
# ['在', '孩子', '學習', '的', '階段', '我們', '要', '怎麼', '去', '關心', '孩子', '幫助', '孩子', '學習', '課業', '呢'] ['我', '覺得', '讓', '孩子', '自動', '自動自發', '自發', '的', '學習', '是', '很重', '重要', '的']
# ['這', '個', '實驗', '實在', '是', '太', '聰明', '了', '啦', '不是', '是你', '想', '的', '方法', '你', '也', '能', '這麼', '開心', '喔'] ['我', '當然', '開心', '啦']
# ['你', '擅長', '的', '年菜', '是', '哪', '一', '道', '呢'] ['我', '最', '拿手', '的', '是', '這一', '道', '丁香', '豬手', '招福', '福壽']
# ['都是', '是你', '啦', '出', '什', '麼', '餿主意', '主意', '嘛', '這', '怎麼', '能', '怪', '我', '是你', '自己', '叫', '我', '幫', '你', '想', '辦法', '的'] ['對', '啦', '對', '啦', '反正', '衰', '的', '又', '不是', '是你']
# ['我是', '是有', '聽說', '說成', '浩', '蠻', '有', '這', '方面', '的', '才華', '的'] ['因為', '我', '喜歡', '去', '知道', '各', '種', '不同', '的', '知識']
# ['應該', '是', '那', '個', '顏色', '很怪', '所以', '才', '叫', '怪', '水', '對', '不對', '還是', '說', '其實', '實是', '那', '個', '水裡', '裡面', '有', '什', '麼', '水怪'] ['什', '麼', '怪', '水', '以前', '一直', '直說', '這是', '毒龍', '龍潭']
# ['爸爸', '爸媽', '媽媽', '離婚', '之後'] ['我', '跟', '爸爸', '一起', '住']
# ['你', '越', '是不', '甩', '他', '不理', '他'] ['他', '越', '是有', '可能', '回來', '找', '你', '的', '啦']
# ['這', '話', '怎麼', '怎麼說', '呢'] ['接下', '接下來', '下來', '我們', '不先', '急', '著', '教', '手語']
# ['明天', '考', '英文', '你', '看', '國文', '做', '什', '麼'] ['我', '在', '溫習', '我等', '等一下', '一下', '就', '看', '英文', '文了']
# ['因為', '我們', '都', '知道', '馮凱', '導演', '其實', '實在', '電視', '電視圈', '非常', '有名', '拍', '了', '很多', '全', '台灣', '台灣人', '人都', '等', '著'] ['每天', '等', '著', '看', '的', '電視', '電視劇']
# ['老闆', '說', '搶不到', '死人', '了', '啦', '夭壽', '喔', '吃', '太快', '會', '弄破', '破碗', '啦', '慢慢', '來', '就好', '好了'] ['快點', '喔', '你們', '這', '團', '每', '次', '都', '最', '慢', '啦']
# ['江', '議員', '您好', '今天', '很', '高興', '在', '這裡', '跟', '您', '碰面'] ['我', '也', '很', '高興', '來', '參加', '活動']
# ['在', '超級', '超級市場', '市場', '或', '魚市', '魚市場', '市場', '買', '蝦', '或是', '買', '魚', '光', '看', '顏色', '不一', '不一定', '一定', '可以', '證明', '牠們', '的', '新鮮', '新鮮度', '鮮度'] ['還要', '用', '鼻子', '聞聞', '聞聞看', '如果', '你', '有', '聞到', '藥水', '藥水味', '水味', '或是', '臭臭', '的', '刺鼻', '刺鼻味', '就要', '小心', '了']
# ['不然', '我們', '來', '比賽', '啊', '好', '啊', '比', '什', '麼', '我們', '來', '找', '土星', '的', '資料', '看', '誰', '找到', '比較', '較多', '然後', '比較', '有趣', '啊'] ['好', '啊', '要', '比', '就', '比', '啊', '這', '次', '一定', '讓', '你', '認輸']
# ['媽媽', '的', '錯', '要是', '是有', '什', '麼', '事情', '我', '幫', '你', '出面', '解決', '嘛', '你', '還要', '管', '我', '嗎', '你', '已經', '幫倒忙', '了'] ['你不', '不要', '這麼', '說', '嘛', '媽媽', '又', '不是', '是一', '個', '沒有', '腦袋', '的', '人']
# ['而且', '現在', '整個', '大環', '環境', '經濟', '不景氣', '景氣'] ['每', '個', '人都', '都要', '想', '辦法', '賺錢', '餬口']
# ['Zoy', '一方面', '方面', '抱', '著', '貪玩', '的', '心情', '打蠟', '另一', '另一方面', '一方面', '方面', '希望', '多', '賺', '點', '錢'] ['可以', '請', '陳喬恩', '喬恩', '吃', '糖果']
# ['現在', '全', '班', '就', '只剩', '剩下', '你', '一', '個', '人', '沒有', '交', '你', '這樣', '我很', '很難', '做', '事', '耶', '我', '又', '不是', '是故', '故意', '的', '就', '真的', '忘了', '帶', '嘛', '我不', '不管', '啦', '你', '要', '趕快', '想', '辦法'] ['全', '班', '所有', '同學', '都', '願意', '意為', '你', '加油', '打氣']
# ['老師', '這是', '是我', '自己', '做', '的', '餅乾', '請你', '嚐嚐', '看', '謝謝', '這', '餅乾', '好', '精緻', '看到', '外表', '就', '覺得', '很好', '好吃', '你', '一定', '花', '了', '很多', '多心', '心思', '是', '媽媽', '厲害', '我只', '只是', '照', '她', '方法', '做', '而已'] ['好好', '好吃', '如果', '不', '跟', '老師', '說', '老師', '一定', '覺得', '這是', '在', '外面', '買', '的']
# ['葉大', '大叔', '想要', '請問', '你', '在', '這', '行李', '行李箱', '裡面', '你', '都', '裝', '了', '些', '什', '麼', '東西', '啊'] ['裡面', '有帳', '帳棚', '書', '和', '隨時', '要', '看', '的', '地圖']
# ['以前', '你們', '都', '吃', '什', '麼'] ['吃', '番薯', '啊', '吃飯', '啊', '番薯', '和', '米', '一起', '煮', '啊']
# ['我', '以為', '兒子', '回來', '了', '他還', '還沒', '回來', '啊', '還沒', '呢', '去', '哪裡', '呀'] ['我', '現在', '有', '多麼', '想要', '一', '支', '手機', '了', '吧']
# ['你們', '洗澡', '的', '地方', '上面', '怎麼', '會', '有', '個', '洞'] ['因為', '晚上', '洗澡', '的', '時候', '可以', '看到', '很多', '星星']
# ['你', '要不', '要不要', '不要', '上去', '拜拜', '一下', '要', '上去', '拜拜', '喔', '上去', '拜拜', '一下'] ['好', '那', '我', '先', '上去', '拜拜']
# ['你們', '有沒有', '沒有', '覺得', '老師', '故意', '偏袒', '珮', '綺', '啊', '可是', '老師', '說', '的', '也', '有道', '道理', '啊', '事情', '又', '還沒', '沒有', '查清', '清楚'] ['事情', '我會', '查清', '清楚', '的']
# ['你知', '知道', '我們', '聽障', '障朋友', '朋友', '有', '哪', '些', '方法', '可以', '表達', '自己', '的', '意見', '嗎'] ['我知', '知道', '有用', '手語', '啦', '用', '寫', '的', '啦', '還', '有', '看', '唇語', '啦', '大概', '就是', '這', '些', '吧']
# ['我', '想到', '一', '個', '好', '辦法', '但是', '得', '要', '同學', '配合', '才', '行', '喔', '我', '相信', '同學', '願意', '的'] ['走', '我們', '先', '和', '梁', '老師', '商量']
# ['你', '早餐', '做', '些', '什', '麼', '菜'] ['做', '餛飩', '湯', '跟', '饅頭', '這樣', '這樣子', '樣子']
# ['你', '有沒有', '沒有', '想', '過', '以後', '你', '兒子', '長大', '了', '要', '讓他', '去', '學', '一', '些', '什', '麼', '才藝'] ['你', '怎麼', '不', '問問', '神奇', '海螺', '呢', '原來', '是你', '兒子', '做', '的']
# ['美術', '美術館', '裡面', '有好', '好多', '好大', '的', '東西', '真', '好玩'] ['只要', '一', '進去', '裡面', '我就', '不', '想出', '想出來', '出來', '了']
# ['梁', '碧', '珊', '今天', '缺席', '嗎', '有沒有', '沒有', '託', '同學', '請假', '呀', '她', '昨天', '從', '訓導', '訓導處', '回來', '以後', '就', '跟', '她', '爸爸', '爸媽', '媽媽', '媽回', '回家', '了', '啦', '好', '吧', '那', '我們', '繼續', '上課'] ['早就', '勸', '過', '她', '不要', '隨便', '找', '劉', '老師', '的', '麻煩', '誰', '不知', '知道', '劉', '老師', '最', '嚴格', '了']
# ['談戀愛', '戀愛', '的', '時候', '只有', '幾', '個', '好朋友', '朋友', '知道', '可是', '是一', '一分', '分手'] ['可是', '國強', '他', '就是', '就是說', '我', '太', '認真']
# ['你', '覺得', '我', '那樣', '做', '真的', '能', '感動', '詠', '真', '嗎'] ['當然', '會', '啊', '如果', '你', '對', '我', '這麼', '好', '的', '話', '我', '也會', '感動', '得', '痛哭', '痛哭流涕', '流涕', '的']
# ['可不可以', '不可', '不可以', '可以', '先', '向', '觀眾', '朋友', '朋友們', '友們', '問', '聲', '好'] ['請問', '您', '這', '個', '外號', '是', '怎麼', '來', '的', '啊']
# ['如果', '要', '送', '朋友', '的', '話', '哪', '一', '種', '最', '能', '表達', '自己', '的', '誠意'] ['這', '首', '歌', '我會', '唱', '我', '唱給', '給你', '你們', '聽好', '好不', '好不好', '不好']
# ['不過', '過人', '的', '電阻', '太大', '如果', '電壓', '夠大', '的', '話'] ['電流', '就', '可以', '通過', '過人', '人體', '了']
# ['老師', '你', '其實', '不用', '那麼', '辛苦', '嘛', '你', '寫', '的', '課本', '上', '都有', '啊'] ['你', '趕快', '把', '黑板', '上', '老師', '寫', '的', '抄下', '抄下來', '下來']
# ['陳', '康', '的', '苗條', '身材', '變胖', '之後', '不知', '知道', '是', '什', '麼', '樣', '的', '情形', '你', '有沒有', '沒有', '特別', '把', '以前', '的', '照片', '帶來', '跟', '觀眾', '朋友', '朋友們', '友們', '們分', '分享'] ['有', '啊', '我', '帶', '了', '照片', '給', '大家', '家傳', '傳閱', '一下', '好不', '好不好', '不好']
# ['你', '可以', '跟', '你', '朋友', '講', '說', '如果', '賣', '不', '出去', '的', '話', '也', '可以', '出租'] ['搜尋', '這', '個', '網址', '就', '可以', '找到', '相關', '訊息']
# ['你', '決定', '要', '選', '誰', '了沒', '沒有', '快點', '做', '決定', '是', '喔', '很多', '多人', '人投', '了', '嗎', '那', '現在', '誰', '最多', '票', '拜託', '想', '也', '知道', '一定', '是', '溫柔', '又', '漂亮', '的', '祐', '禎'] ['真', '巧', '我', '也是', '投', '她']
# ['還', '有', '誰', '還沒', '沒有', '投票', '的', '投', '什', '麼', '票', '不關', '關女', '女生', '的', '事'] ['什', '麼', '不', '干', '女生', '的', '事', '拿來', '我', '看']
# ['因為', '我們', '兩', '個', '從小', '就', '認識', '認識到', '現在', '然後', '我們', '一起', '在', '水溝', '尿', '過', '無', '數', '次', '的', '尿'] ['我們', '們大', '大口', '口吃', '吃下', '下肚', '的', '海鮮']
# ['就', '你', '可以', '看', '啊', '這', '些', '都是', '啊', '所以', '你', '也', '很', '漂亮', '是不', '不是'] ['我', '媽媽', '心', '很', '漂亮', '就', '很好', '的', '家庭', '家庭主', '主婦', '吧']
# ['看不出來', '出來', '我', '在', '練功', '喔'] ['你', '怎麼', '這樣', '這樣子', '樣子', '啊', '小氣']
# ['為什麼', '不', '走', '岸邊'] ['我們', '是', '希望', '遊客', '可以', '自動', '自動自發', '自發', '不要', '要去', '抓', '裡面', '的', '螃蟹']
# ['一樣', '耶', '有', '默契', '喔', '誰', '跟', '你', '有', '默契', '我', '跟', '舒', '琪', '借', '的', '太', '巧', '了', '我是', '跟', '千', '晏', '借', '的'] ['看起來', '起來', '好像', '不是', '太', '開心', '耶']
# ['老師', '這是', '是我', '阿嬤', '做', '的', '飛魚', '魚乾', '要', '給', '老師', '吃', '的', '飛魚', '綠島', '也', '有', '飛魚', '我還', '以為', '蘭嶼', '才', '有', '耶'] ['綠島', '也', '有', '飛魚', '而且', '成', '浩', '他', '阿嬤', '做', '的', '飛魚', '魚乾', '非常', '好吃', '耶']
# ['老闆', '我們', '來', '這裡', '遊玩', '的', '想', '問', '一下', '一下路', '那', '個', '舞鶴', '怎麼', '走'] ['你', '現在', '出去', '看到', '紅綠燈', '綠燈', '往', '南', '走', '差不', '差不多', '十分', '十分鐘', '分鐘', '就', '到', '了']
# ['後來', '再', '隔', '比較', '麻煩', '就是', '就是說', '它', '跟', '原來', '的', '負重', '的', '結構', '會', '不一', '一樣', '所以', '地震', '的', '時候'] ['太高', '的', '火災', '你不', '不容', '容易', '滅']
# ['曉', '書', '玫瑰', '玫瑰花', '送給', '給你', '是不', '不是', '很', '漂亮', '呢'] ['好', '漂亮', '喔']
# ['我', '今天', '找', '你來', '是', '想', '請你', '幫忙', '的', '事', '成', '之後', '自有', '重賞'] ['只要', '我能', '幫忙', '必', '效', '犬馬', '犬馬之勞']
# ['老師', '你', '今天', '沒有', '跟', '蕙', '馨', '一起', '走', '她', '有事', '要', '集合'] ['那', '老師', '陪', '你', '走到', '車站', '囉']
# ['姵', '蓁', '你', '的', '錶', '壞', '了', '啊', '可是', '這', '好像', '不是', '是你', '的', '錶'] ['沒', '啦', '是', '佳', '宏', '的']
# ['但是', '是我', '的', '兒子', '喜歡', '的', '有一', '個', '人', '說不定', '不定', '跟', '你', '一樣', '是誰', '住', '在', '深海', '的', '大鳳', '鳳梨', '裡'] ['聊聊', '對', '工作', '的', '想法']
# ['你', '今天', '怎麼', '沒', '去', '上課'] ['阿嬤', '放心', '啦', '我會', '帶', '你', '一起', '去', '啊']
# ['學姐', '學姐', '那', '我', '什', '麼', '時候', '可以', '開始', '賣房', '房子', '啊'] ['不行', '啦', '妳', '還', '太', '嫩', '什', '麼', '事情', '都不', '不會']
# ['那你', '現在', '差不', '差不多', '一', '個', '禮拜', '要', '花', '多久', '時間', '騎', '馬'] ['我', '已經', '做', '了一', '個', '重大', '的', '決定']
# ['我們', '還要', '走', '多', '遠'] ['大概', '差不', '差不多', '再', '走', '三', '百', '公尺']
# ['不會', '啦', '這', '種', '碳酸', '它', '是', '鹼性', '的', '啦'] ['這', '個', '酸鹼', '酸鹼值', '我就', '就有', '學', '過', '如果', '如果說', '這', '個', 'pH', '值大', '大於', '七', '的', '它', '就是', '鹼性', '的']
# ['他', '身上', '上香', '香水', '好香', '你', '也', '有', '聞到', '啊', '那是', '什', '麼', '牌子', '的', '香水', '啊'] ['這是', '是我', '的', '名字']
# ['陳', '韋', '辰', '你又', '不', '吃飯', '啦', '我', '在', '減肥', '光', '靠', '餓肚子', '肚子', '是不', '不能', '減肥', '的'] ['誰', '說', '的', '我', '已經', '瘦', '了', '兩', '公斤', '了']
# ['偉', '傑', '人', '真', '好', '班上', '男生', '應該', '多', '跟', '他', '學學', '才', '對'] ['對', '偉', '傑', '做人', '有禮', '禮貌', '服裝', '儀容', '整齊', '又', '乾淨']
# ['我', '比較', '想', '知道', '的', '是', '不管', '是', '單親', '爸爸', '或是', '單親', '單親媽', '媽媽'] ['對', '孩子', '的', '教育', '方式']
# ['他', '很會', '藏', '喔', '隨便', '那', '個', '書櫃', '啊', '那', '個', '抽屜', '啊', '到處', '都是', '都是', '酒瓶', '今天', '有', '嗎', '今天', '我們', '來', '查', '找找', '看'] ['沒有', '啦', '今天', '已經', '克制', '得', '很好', '好了', '啦']
# ['你們', '覺得', '上', '陶藝', '課', '最快', '快樂', '是', '什', '麼', '事'] ['可以', '自己', '創造']
# ['小莉', '知不知道', '不知', '知道', '妍', '如', '跑', '哪兒', '去', '了', '不知', '知道', '今天', '還沒', '看到', '她'] ['她', '爸爸', '好像', '搬回', '搬回去', '回去', '台灣', '一年', '只', '回來', '看', '她', '一', '兩', '次']
# ['你', '看', '他', '這麼', '高', '這麼', '壯', '我', '怎麼', '可能', '贏', '他'] ['什', '麼', '我', '壯', '你', '也不', '弱', '好不', '好不好', '不好']
# ['叔叔', '那', '我們', '要', '怎麼', '過去', '搭', '這一', '艘', '出發', '了', '哇塞', '好棒', '喔', '第', '一', '次', '在日', '日月', '日月潭', '上面'] ['坐', '著這', '種', '小船', '在', '湖上', '上面', '走']
# ['你', '明天', '要', '考試', '功課', '寫完', '了', '嗎'] ['明天', '只是', '小考', '而已', '沒關係', '關係', '啦']
# ['人家', '下班', '了', '啦', '要是', '是不', '趕快', '存', '起來', '到時', '到時候', '時候', '一定', '會', '露出', '露出馬腳', '出馬', '馬腳', '的'] ['豆油', '豆油伯', '你', '也不', '不要', '那麼', '緊張', '今天', '來不及', '不及', '明天', '再', '拿去', '寄', '不', '就', '得了', '嗎']
# ['老師', '他不', '不是', '壞人', '啦', '老師', '並', '沒有', '說', '他是', '壞人', '啊', '只是', '希望', '你們', '在', '公共', '場所', '能夠', '提高', '警覺'] ['好', '耶', '譚', '老師', '跟', '織田', '田裕', '二', '比', '比', '看', '誰', '比較', '強']
# ['這', '點', '想', '請教', '鄭', '組長', '規畫', '無', '障礙', '環境', '要', '考慮', '哪', '些', '問題', '有沒有', '沒有', '針對', '聽障', '設計', '的', '呢', '當然', '我們', '現在', '技術', '規則'] ['大', '部分', '都是', '是以', '視障', '跟', '肢障', '的', '為主']
# ['以後', '數學', '數學課', '我就', '跟', '你', '換位', '位置', '為什麼', '要', '換位', '位置'] ['沒有', '有為', '為什麼', '我就', '就是', '是要', '跟', '你', '換位', '位置']
# ['賈', '晨', '舒', '琪', '她們', '兩', '個', '怎麼', '了', '一', '個', '星期', '都不', '跟', '對方', '說話', '誰', '知道', '一下', '像', '黏', '巴', '達', '一下', '連', '看', '都不', '看', '對方', '你們', '女生', '好奇', '奇怪'] ['你', '才', '奇怪']
# ['都是', '是你', '啦', '出', '什', '麼', '餿主意', '主意', '嘛'] ['這', '怎麼', '能', '怪', '我', '是你', '自己', '叫', '我', '幫', '你', '想', '辦法', '的']
# ['不要', '管', '我', '了', '我', '自己', '在', '這邊', '練習', '那', '怎麼', '行'] ['不要', '擔心', '教練', '練就', '在', '這邊']
# ['奕瑄', '她', '爸爸', '之前', '是我', '我們', '那一', '里', '的', '里長', '但', '因為', '盜用', '公款', '被', '判', '坐牢', '既然', '奕瑄', '她', '爸爸', '會', 'A', '錢', '那', '我們', '把', '校外', '外教', '教學', '的', '費用', '交給', '給她', '是不', '不是', '是也', '很', '危險', '啊'] ['你們', '這樣', '橫衝直撞', '直撞', '真的', '很', '危險', '耶']
# ['你知', '知道', '有沒有', '沒有', '熟', '嗎'] ['我知', '知道', '看', '外面', '就', '知道', '了']
# ['您', '平常', '有', '參與', '聽障', '障團', '障團體', '團體', '常', '會', '用', '的', '手語', '是', '什', '麼'] ['我們', '平常', '一般', '遇到', '聾人', '的', '話', '就', '先', '跟', '他', '問好']
# ['那時', '時候', '我要', '照顧', '孩子'] ['還', '有', '小孩', '要', '養']
# ['那', '這', '個', '戲', '裡面', '當然', '有', '很多', '東西', '是', '可以', '值得', '一一', '抽出', '抽出來', '出來', '談', '的', '比方', '比方說', '像', '它', '的', '對白'] ['去', '判斷', '你', '的', '每', '一', '個', '鏡頭']
# ['濂', '僑', '你', '有沒有', '沒有', '想', '過', '你', '以後', '後退', '退休', '之後', '要', '做', '什', '麼', '啊'] ['退休', '之後', '啊', '當然', '是有', '有空', '就', '約', '朋友']
# ['老師', '喜歡', '的', '類型', '像', '姵', '蓁', '一樣', '常常', '笑臉', '迎人', '果然', '老師', '欣賞', '的', '類型', '也是', '異於', '常人'] ['老師', '不行', '啦', '你', '選', '的', '可是', '是我', '我們', '班上', '的', '恰查', '某']
# ['小微', '呀', '你', '在', '摸', '什', '麼', '啊', '都', '幾', '點', '啦'] ['好', '啦', '馬上', '就好', '好了']
# ['房仲', '房仲業', '仲業', '有', '很多', '多事', '要', '學', '那一', '本', '重要', '的', '寶典', '書', '買', '了沒', '沒有'] ['有', '我', '第一天', '就', '買', '了', '學長', '姐', '規定', '的']
# ['阿公', '幫幫', '我', '把', '這', '個', '剪掉', '剪掉', '做', '什', '麼'] ['拿來', '炫耀', '一下']
# ['奇怪', '真', '奇怪', '什', '麼', '事情', '很', '奇怪'] ['我', '在', '看', '那', '個', 'VCD']
# ['裡面', '的', '水生', '植物', '是我', '我們', '照顧', '的', '那你', '你們', '照顧', '顧得', '很好', '耶', '等一下', '一下', '這', '個', '可愛', '的', '陶瓷', '作品'] ['也是', '是你', '你們', '自己', 'DIY', '做', '的', '嗎']
# ['姊姊', '珮', '綺', '常', '對', '妹妹', '珮', '華', '的', '金錢', '觀', '不以為然', '以為', '然', '她', '常常', '被', '我', '罵'] ['我', '覺得', '說', '她', '花錢', '沒有', '有理', '理智']
# ['因為', '我有', '有一', '個', '更', '神奇', '的', '玩具', '比', '你', '的', '玩具', '更', '酷'] ['真的', '嗎', '是', '什', '麼', '新鮮', '的', '玩具', '給', '我', '看看', '嘛']
# ['好可愛', '可愛', '喔', '這是', '什', '麼', '這是', '瓢蟲'] ['姊姊', '你不', '不怕', '蟲蟲', '喔']
# ['只要', '你', '跟', '我一', '一起', '起用', '用功', '我們', '一定', '會考', '考上', '同一', '所', '高中', '的', '可是', '是我', '我怕', '我', '考', '不好'] ['有我', '在', '你', '怕', '什', '麼', '我', '打電話', '電話', '來', '就是', '是要', '跟', '你', '說明', '明天', '考試', '的', '重點']
# ['我', '警告', '你', '喔', '不要', '讓我', '再', '接到', '學校', '打來', '來電', '來電話', '電話', '喔'] ['好', '啦']

# %%
with open(version + '_answer.csv', 'w', encoding='utf-8') as out:
    out.write('Id,Answer\n')
    for idx, p in enumerate(predict):
        out.write(str(idx) + ',' + str(p) + '\n')
